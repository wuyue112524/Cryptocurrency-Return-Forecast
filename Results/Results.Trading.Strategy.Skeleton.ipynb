# %%
## Keras for deep learning
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional
from keras.models import Sequential

## Scikit learn for mapping metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#for logging
import time

##matrix math
import math

##plotting
import matplotlib.pyplot as plt
from sklearn import preprocessing

import pandas as pd
import os
import numpy as np
import time
import datetime

##matrix math
import math


os.chdir('D:/Graduate Courses/2019 Dissertation/Data/Other.coins')
print("Current Working Directory " , os.getcwd())
# Out:
# Using TensorFlow backend.
# Current Working Directory  D:\Graduate Courses\2019 Dissertation\Data\Other.coins

# %%
# %load SM
#!/usr/bin/env python

# In[ ]:


#load the data
def load_data(filename, window_length,percent):
    """
    Loads the bitcoin data
    
    Arguments:
    filename -- A string that represents where the .csv file can be located
    sequence_length -- An integer of how many days should be looked at in a row
    
    Returns:
    if window=30
    X_train -- A tensor of shape (2492, 30, 105) that will be inputed into the model to train it
    Y_train -- A tensor of shape (2492,) that will be inputed into the model to train it
    X_test -- A tensor of shape (623, 30, 105) that will be used to test the model's proficiency
    Y_test -- A tensor of shape (623,) that will be used to check the model's predictions
    Y_daybefore -- A tensor of shape (623,) that represents the price of bitcoin the day before each Y_test value
    """
    
    #Read the data file
    dataset_total = pd.read_csv(filename,na_values='n/a',parse_dates=['Date'])
    dataset_total=dataset_total.drop(['Unnamed: 0',], axis=1)

    # Set index
    dataset_total.set_index('Date', inplace=True)
    dataset_total= dataset_total.loc[:, (dataset_total!= 0).any(axis=0)]

    #normalize dataset
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range = (0, 1))
    dataset_total_scaled = sc.fit_transform(dataset_total)
    X_normal=dataset_total_scaled[:,:-1]
    Y=dataset_total_scaled[:,-1]
    
   
    #Convert the data to a 3D array (a x b x c) 
    #Where a is the number of days, b is the window size, and c is the number of features in the data file
    data = X_normal.tolist()
    result = []
    for index in range(len(data) - window_length):
        result.append(data[index: index + window_length])

    data_reshape=np.array(result)
    data_reshape.shape

    #Splitting data set into training (First 80% of data points) and testing data (last 20% of data points)
    split_line = round(percent * data_reshape.shape[0])
    X_train = data_reshape[:int(split_line), :]
    Y_train = Y[window_length:int(split_line)+window_length]
    X_test = data_reshape[int(split_line):,:]
    Y_test = Y[int(split_line)+window_length:]
    Y_daybefore = Y[int(split_line)+window_length-1:-1]
    
    #New
    line= int(split_line)+window_length
    
    return X_train, Y_train, X_test, Y_test, window_length,dataset_total,Y_daybefore,line

def initialize_model(dropout_rate):
    """
    Initializes and creates the model to be used
    
    Arguments:
    dropout_rate -- A decimal representing how much dropout should be incorporated at each level, in this case 0.2
    activation_function -- A string to define the activation_function, in this case it is linear
    loss_function -- A string to define the loss function to be used, in the case it is mean squared error
    optimizer -- A string to define the optimizer to be used, in the case it is adam
    
    Returns:
    model -- A 3 layer RNN with 100*dropout_value dropout in each layer that uses activation_function as its activation
             function, loss_function as its loss function, and optimizer as its optimizer
    """
  
    #Build the model
    model=Sequential()

    input_shape=(window_length, X_train.shape[-1])

    optimizer='adam'
    loss='mean_squared_error'
    
    model.add(LSTM(units = 32, return_sequences = True, input_shape = input_shape))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units = 32, activation='relu'))
    
    
    model.add(LSTM(units = 32, return_sequences = True))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units = 32, activation='relu'))
    
    model.add(LSTM(units = 32, return_sequences = False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units = 1,activation='linear'))
   
    
              
    model.compile(optimizer =optimizer, loss = loss)

    
    return model

#Training the model

def fit_model(model, X_train, Y_train, batch_num, num_epoch, val_split):
    """
    Fits the model to the training data
    
    Arguments:
    model -- The previously initalized 3 layer Recurrent Neural Network
    X_train -- A tensor of shape (2492, 30, 105) that represents the x values of the training data
    Y_train -- A tensor of shape (2492,) that represents the y values of the training data
    batch_num -- An integer representing the batch size to be used, in this case 100
    num_epoch -- An integer defining the number of epochs to be run, in this case 100
    val_split -- A decimal representing the proportion of training data to be used as validation data
    
    Returns:
    model -- The 3 layer Recurrent Neural Network that has been fitted to the training data
    training_time -- An integer representing the amount of time (in seconds) that the model was training
    """
   

    #Train the model on X_train and Y_train
    model.fit(X_train, Y_train, batch_size= batch_num, nb_epoch=num_epoch, validation_split= val_split)

    return model

# test the model
def test_model(model, X_test, Y_test):
    """
    Test the model on the testing data
    
    Arguments:
    model -- The previously fitted 3 layer Recurrent Neural Network
    X_test -- A tensor of shape (623, 30, 105) that represents the x values of the testing data
    Y_test -- A tensor of shape (623,) that represents the y values of the testing data
    unnormalized_bases -- A tensor of shape (623,) that can be used to get unnormalized data points
    
    Returns:
    y_predict -- A tensor of shape (623,) that represnts the normalized values that the model predicts based on X_test
    real_y_test -- A tensor of shape (623,) that represents the actual prices of bitcoin throughout the testing period
    real_y_predict -- A tensor of shape (623,) that represents the model's predicted prices of bitcoin
    fig -- A branch of the graph of the real predicted prices of bitcoin versus the real prices of bitcoin
    """
    #Test the model on X_Test
    Y_norm = model.predict(X_test)
    
    # normalize predicted y
    Y_original=dataset_total.iloc[:,-1]
    Y_max=Y_original.max()
    Y_min=Y_original.min()
    real_y_predict = Y_norm *(Y_max-Y_min)+Y_min
    
    # normalize Y_test
    real_y_test = Y_test *(Y_max-Y_min)+Y_min
    
    # normalize real Y_daybefore
    real_y_daybefore = Y_daybefore * (Y_max-Y_min)+Y_min

    #Plot of the predicted prices versus the real prices
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.set_title("Bitcoin Return Over Time")
    plt.plot(real_y_predict, color = 'green', label = 'Predicted Return')
    plt.plot(real_y_test, color = 'red', label = 'Real Return')
    ax.set_ylabel("Return")
    ax.set_xlabel("Time (Days)")
    ax.legend()
    
    return Y_norm, real_y_test, real_y_predict, fig, real_y_daybefore

#evaluate change in return

def return_change(real_y_daybefore, real_y_test, real_y_predict):
    """
    Calculate the percent change between each value and the day before
    
    Arguments:
    real_y_daybefore -- A tensor of shape (623,) that represents the prices of each day before each price in Y_test
    Y_test -- A tensor of shape (623,) that represents the normalized y values of the testing data
    y_predict -- A tensor of shape (623,) that represents the normalized y values of the model's predictions
    
    Returns:
    delta_predict -- A tensor of shape (623, ) that represents the difference between predicted and day before values
    delta_real -- A tensor of shape (623, ) that represents the difference between real and day before values
    fig -- A plot representing percent change in bitcoin price per day,
    """
    return_change_real = real_y_test - real_y_daybefore
    real_y_predict_reshape= np.reshape(real_y_predict,(real_y_predict.shape[0],))
    return_change_predict = real_y_predict_reshape - real_y_daybefore

    fig_2 = plt.figure(figsize=(10, 6))
    ax = fig_2.add_subplot(111)
    ax.set_title("Change in Bitcoin Return Per Day")
    plt.plot(return_change_predict, color='green', label = 'Predicted Return Change')
    plt.plot(return_change_real, color='red', label = 'Real Return Change')
    plt.ylabel("Return Change")
    plt.xlabel("Time (Days)")
    ax.legend()
    plt.show()
    return  return_change_predict, return_change_real, fig_2

def binary_return(return_change_predict,return_change_real):
    """
    Converts return change to a binary 1 or 0, where 1 is an increase and 0 is a decrease/no change
    
    Arguments:
    delta_predict -- A tensor of shape (623, 1) that represents the predicted percent change in price
    delta_real -- A tensor of shape (623, 1) that represents the real percent change in price
    
    Returns:
    delta_predict_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_predict
    delta_real_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_real
    """
    #Empty arrays where a 1 represents an increase in price and a 0 represents a decrease in price
    return_change_predict_1_0 = np.empty(return_change_predict.shape)
    return_change_real_1_0 = np.empty(return_change_real.shape)

    #If the change in price is greater than zero, store it as a 1
    #If the change in price is less than zero, store it as a 0
    for i in range(return_change_predict.shape[0]):
        if return_change_predict[i] > 0:
            return_change_predict_1_0[i] = 1
        else:
            return_change_predict_1_0[i] = 0
  
    for i in range(return_change_real.shape[0]):
        if  return_change_real[i] > 0:
            return_change_real_1_0[i] = 1
        else:
            return_change_real_1_0[i] = 0
    return return_change_predict_1_0, return_change_real_1_0

def find_positives_negatives(return_change_predict_1_0, return_change_real_1_0):
    """
    Finding the number of false positives, false negatives, true positives, true negatives
    
    Arguments: 
    delta_predict_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_predict
    delta_real_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_real
    
    Returns:
    true_pos -- An integer that represents the number of true positives achieved by the model
    false_pos -- An integer that represents the number of false positives achieved by the model
    true_neg -- An integer that represents the number of true negatives achieved by the model
    false_neg -- An integer that represents the number of false negatives achieved by the model
    """
    #Finding the number of false positive/negatives and true positives/negatives
    true_pos = 0
    false_pos = 0
    true_neg = 0
    false_neg = 0
    for i in range(return_change_real_1_0.shape[0]):
        real = return_change_real_1_0[i]
        predicted = return_change_predict_1_0[i]
        if real == 1:
            if predicted == 1:
                true_pos += 1
            else:
                false_neg += 1
        elif real == 0:
            if predicted == 0:
                true_neg += 1
            else:
                false_pos += 1
    return true_pos, false_pos, true_neg, false_neg

# Classification function

def classify_range(variable_name):
    
    classification[variable_name+'_range']=0

    for i in range(classification.shape[0]):
        if classification[variable_name][i]<=0.002 and classification[variable_name][i]>=-0.002:
            classification[variable_name+'_range'][i]=0
        
        elif classification[variable_name][i]<=-0.002 and classification[variable_name][i]>=-0.004:
            classification[variable_name+'_range'][i]=-1
        
        elif classification[variable_name][i]<=-0.004 and classification[variable_name][i]>=-0.006:
            classification[variable_name+'_range'][i]=-2
        
        elif classification[variable_name][i]<=-0.006 and classification[variable_name][i]>=-0.008:
            classification[variable_name+'_range'][i]=-3
        
        elif classification[variable_name][i]<=-0.008 and classification[variable_name][i]>=-0.010:
            classification[variable_name+'_range'][i]=-4
        
        elif classification[variable_name][i]<=-0.010 and classification[variable_name][i]>=-0.012:
            classification[variable_name+'_range'][i]=-5
        
        elif classification[variable_name][i]<=-0.012 and classification[variable_name][i]>=-0.014:
            classification[variable_name+'_range'][i]=-6
        
        elif classification[variable_name][i]<=-0.014 and classification[variable_name][i]>=-0.016:
            classification[variable_name+'_range'][i]=-7
        
        elif classification[variable_name][i]<=-0.016 and classification[variable_name][i]>=-0.018:
            classification[variable_name+'_range'][i]=-8
        
        elif classification[variable_name][i]<=-0.018 and classification[variable_name][i]>=-0.020:
            classification[variable_name+'_range'][i]=-9
        
        elif classification[variable_name][i]<=-0.020:
            classification[variable_name+'_range'][i]=-10
        
        #positive value
        elif classification[variable_name][i]<=0.004 and classification[variable_name][i]>=0.002:
            classification[variable_name+'_range'][i]=1
        
        elif classification[variable_name][i]<=0.006 and classification[variable_name][i]>=0.004:
            classification[variable_name+'_range'][i]=2
        
        elif classification[variable_name][i]<=0.008 and classification[variable_name][i]>=0.006:
            classification[variable_name+'_range'][i]=3
        
        elif classification[variable_name][i]<=0.010 and classification[variable_name][i]>=0.008:
            classification[variable_name+'_range'][i]=4
        
        elif classification[variable_name][i]<=0.012 and classification[variable_name][i]>=0.010:
            classification[variable_name+'_range'][i]=5
        
        elif classification[variable_name][i]<=0.014 and classification[variable_name][i]>=0.012:
            classification[variable_name+'_range'][i]=6
        
        elif classification[variable_name][i]<=0.016 and classification[variable_name][i]>=0.014:
            classification[variable_name+'_range'][i]=7
        
        elif classification[variable_name][i]<=0.018 and classification[variable_name][i]>=0.016:
            classification[variable_name+'_range'][i]=8
        
        elif classification[variable_name][i]<=0.020 and classification[variable_name][i]>=0.018:
            classification[variable_name+'_range'][i]=9
         
        else:
            classification[variable_name+'_range'][i]=10
    return classification

def find_the_successful_rate(classification):
    successful_number=0
    for i in range(classification.shape[0]):
        if classification['real_y_test_range'][i]==classification['real_y_predict_range'][i]:
            successful_number+=1
    successful_rate=round(successful_number/classification.shape[0],4)
    return successful_rate

# %%
#Compile together
#EOS 
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("merge_EOS-USD.csv", 30, 0.6880)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 32, 100, .3)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("EOS Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_EOS.csv')
# Out:
# (396, 30, 98)
# (396,)
# (180, 30, 98)
# (180,)
# 30
# (180,)
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30, 32)            16768
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 32)            8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,553
# Trainable params: 35,553
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 277 samples, validate on 119 samples
# Epoch 1/100
# 277/277 [==============================] - 3s 10ms/step - loss: 0.0767 - val_loss: 0.0154
# Epoch 2/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0349 - val_loss: 0.0114
# Epoch 3/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0078
# Epoch 4/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0258 - val_loss: 0.0063
# Epoch 5/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0257 - val_loss: 0.0060
# Epoch 6/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0258 - val_loss: 0.0061
# Epoch 7/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0269 - val_loss: 0.0065
# Epoch 8/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0259 - val_loss: 0.0062
# Epoch 9/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0073
# Epoch 10/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0060
# Epoch 11/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0231 - val_loss: 0.0067
# Epoch 12/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0228 - val_loss: 0.0070
# Epoch 13/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0235 - val_loss: 0.0068
# Epoch 14/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0230 - val_loss: 0.0060
# Epoch 15/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0222 - val_loss: 0.0070
# Epoch 16/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0066
# Epoch 17/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0060
# Epoch 18/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0236 - val_loss: 0.0065
# Epoch 19/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0060
# Epoch 20/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0228 - val_loss: 0.0061
# Epoch 21/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0222 - val_loss: 0.0061
# Epoch 22/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0224 - val_loss: 0.0060
# Epoch 23/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0213 - val_loss: 0.0061
# Epoch 24/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0060
# Epoch 25/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0060
# Epoch 26/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0076
# Epoch 27/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0221 - val_loss: 0.0060
# Epoch 28/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0068
# Epoch 29/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0059
# Epoch 30/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0218 - val_loss: 0.0064
# Epoch 31/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0217 - val_loss: 0.0075
# Epoch 32/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0223 - val_loss: 0.0061
# Epoch 33/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0065
# Epoch 34/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0076
# Epoch 35/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0217 - val_loss: 0.0059
# Epoch 36/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0084
# Epoch 37/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0198 - val_loss: 0.0059
# Epoch 38/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0212 - val_loss: 0.0070
# Epoch 39/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0221 - val_loss: 0.0065
# Epoch 40/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0206 - val_loss: 0.0060
# Epoch 41/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0059
# Epoch 42/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0076
# Epoch 43/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0215 - val_loss: 0.0063
# Epoch 44/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0222 - val_loss: 0.0067
# Epoch 45/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.0070
# Epoch 46/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0217 - val_loss: 0.0065
# Epoch 47/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0217 - val_loss: 0.0068
# Epoch 48/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0214 - val_loss: 0.0059
# Epoch 49/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0212 - val_loss: 0.0089
# Epoch 50/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0188 - val_loss: 0.0068
# Epoch 51/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0218 - val_loss: 0.0079
# Epoch 52/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0222 - val_loss: 0.0062
# Epoch 53/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0085
# Epoch 54/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0064
# Epoch 55/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0113
# Epoch 56/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0072
# Epoch 57/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0061
# Epoch 58/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0072
# Epoch 59/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0209 - val_loss: 0.0076
# Epoch 60/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0198 - val_loss: 0.0084
# Epoch 61/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0084
# Epoch 62/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.0075
# Epoch 63/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0199 - val_loss: 0.0083
# Epoch 64/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0096
# Epoch 65/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0205 - val_loss: 0.0098
# Epoch 66/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0216 - val_loss: 0.0130
# Epoch 67/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0077
# Epoch 68/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0144
# Epoch 69/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.0077
# Epoch 70/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.0089
# Epoch 71/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0206 - val_loss: 0.0097
# Epoch 72/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0086
# Epoch 73/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0125
# Epoch 74/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0090
# Epoch 75/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0185 - val_loss: 0.0105
# Epoch 76/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0094
# Epoch 77/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0191 - val_loss: 0.0117
# Epoch 78/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.0121
# Epoch 79/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.0102
# Epoch 80/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0205 - val_loss: 0.0111
# Epoch 81/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0109
# Epoch 82/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 0.0116
# Epoch 83/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.0107
# Epoch 84/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0205 - val_loss: 0.0091
# Epoch 85/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0100
# Epoch 86/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0105
# Epoch 87/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.0090
# Epoch 88/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0185 - val_loss: 0.0106
# Epoch 89/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0186 - val_loss: 0.0127
# Epoch 90/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.0106
# Epoch 91/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0195 - val_loss: 0.0083
# Epoch 92/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0184 - val_loss: 0.0103
# Epoch 93/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0111
# Epoch 94/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 0.0109
# Epoch 95/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0185 - val_loss: 0.0118
# Epoch 96/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.0114
# Epoch 97/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0185 - val_loss: 0.0142
# Epoch 98/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0183 - val_loss: 0.0133
# Epoch 99/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0181 - val_loss: 0.0116
# Epoch 100/100
# 277/277 [==============================] - 0s 1ms/step - loss: 0.0182 - val_loss: 0.0107
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.047059        0.085464                -10
# 2018-11-26    -0.058642        0.083732                -10
# 2018-11-27     0.081967        0.080861                 10
# 2018-11-28    -0.078788        0.078236                -10
# 2018-11-29    -0.049342        0.073570                -10
# 2018-11-30     0.027682        0.067357                 10
# 2018-12-01    -0.033670        0.061634                -10
# 2018-12-02    -0.097561        0.056609                -10
# 2018-12-03    -0.046332        0.052049                -10
# 2018-12-04    -0.113360        0.049959                -10
# 2018-12-05    -0.155251        0.050430                -10
# 2018-12-06    -0.048649        0.053186                -10
# 2018-12-07     0.056818        0.058012                 10
# 2018-12-08     0.102151        0.063939                 10
# 2018-12-09    -0.048780        0.069120                -10
# 2018-12-10    -0.046154        0.071029                -10
# 2018-12-11     0.080645        0.068763                 10
# 2018-12-12    -0.069652        0.065079                -10
# 2018-12-13    -0.010695        0.059595                 -5
# 2018-12-14     0.043243        0.053189                 10
# 2018-12-15     0.010363        0.052401                  5
# 2018-12-16     0.256410        0.051761                 10
# 2018-12-17     0.102041        0.048397                 10
# 2018-12-18    -0.066667        0.036591                -10
# 2018-12-19     0.111111        0.016045                 10
# 2018-12-20    -0.046429       -0.004148                -10
# 2018-12-21     0.007491       -0.020315                  3
# 2018-12-22     0.066914       -0.029821                 10
# 2018-12-23    -0.013937       -0.031434                 -6
# 2018-12-24    -0.088339       -0.029741                -10
# ...                 ...             ...                ...
# 2019-04-23    -0.049689        0.083636                -10
# 2019-04-24     0.056645        0.088178                 10
# 2019-04-25    -0.008247        0.091208                 -4
# 2019-04-26     0.014553        0.088814                  7
# 2019-04-27    -0.030738        0.079777                -10
# 2019-04-28     0.065539        0.064501                 10
# 2019-04-29    -0.015873        0.051541                 -7
# 2019-04-30     0.002016        0.036067                  1
# 2019-05-01     0.060362        0.021527                 10
# 2019-05-02    -0.022770        0.009860                -10
# 2019-05-03    -0.011650       -0.001407                 -5
# 2019-05-04     0.003929       -0.008912                  1
# 2019-05-05    -0.019569       -0.011127                 -9
# 2019-05-06     0.007984       -0.010839                  3
# 2019-05-07    -0.029703       -0.008241                -10
# 2019-05-08    -0.012245       -0.002304                 -6
# 2019-05-09     0.128099        0.008154                 10
# 2019-05-10    -0.021978        0.022660                -10
# 2019-05-11     0.031835        0.029234                 10
# 2019-05-12     0.092559        0.030828                 10
# 2019-05-13     0.071429        0.027626                 10
# 2019-05-14     0.006202        0.022114                  3
# 2019-05-15    -0.063174        0.017170                -10
# 2019-05-16    -0.031250        0.014187                -10
# 2019-05-17     0.098472        0.015731                 10
# 2019-05-18    -0.032457        0.021128                -10
# 2019-05-19     0.003195        0.024827                  1
# 2019-05-20    -0.055733        0.029122                -10
# 2019-05-21     0.016863        0.031883                  8
# 2019-05-22     0.064677        0.037042                 10
#
#             real_y_predict_range
# Date
# 2018-11-25                    10
# 2018-11-26                    10
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                    10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                    10
# 2018-12-04                    10
# 2018-12-05                    10
# 2018-12-06                    10
# 2018-12-07                    10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                    10
# 2018-12-14                    10
# 2018-12-15                    10
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                     8
# 2018-12-20                    -2
# 2018-12-21                   -10
# 2018-12-22                   -10
# 2018-12-23                   -10
# 2018-12-24                   -10
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                     4
# 2019-05-03                     0
# 2019-05-04                    -4
# 2019-05-05                    -5
# 2019-05-06                    -5
# 2019-05-07                    -4
# 2019-05-08                    -1
# 2019-05-09                     4
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                     8
# 2019-05-16                     7
# 2019-05-17                     7
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    10
# 2019-05-22                    10
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.2333
# C:\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 0.9672184301634705
# Annulized Sharpe Ratio for buy and hold strategy is 0.7832429664222199

# %%
#Compile together
#ETH 
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("merge_ETH-USD.csv", 30, 0.8582)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 32, 100, .3)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("ETH Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_ETH.csv')
# Out:
# (1088, 30, 110)
# (1088,)
# (180, 30, 110)
# (180,)
# 30
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 30, 32)            18304
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_16 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 30, 32)            8320
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_17 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 37,089
# Trainable params: 37,089
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 761 samples, validate on 327 samples
# Epoch 1/100
# 761/761 [==============================] - 4s 6ms/step - loss: 0.0302 - val_loss: 0.0059
# Epoch 2/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0133 - val_loss: 0.0056
# Epoch 3/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0136 - val_loss: 0.0056
# Epoch 4/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0123 - val_loss: 0.0058
# Epoch 5/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0124 - val_loss: 0.0059
# Epoch 6/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0122 - val_loss: 0.0056
# Epoch 7/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0120 - val_loss: 0.0060
# Epoch 8/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0116 - val_loss: 0.0063
# Epoch 9/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0114 - val_loss: 0.0062
# Epoch 10/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0114 - val_loss: 0.0060
# Epoch 11/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0113 - val_loss: 0.0056
# Epoch 12/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0114 - val_loss: 0.0056
# Epoch 13/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0110 - val_loss: 0.0063
# Epoch 14/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0116 - val_loss: 0.0062
# Epoch 15/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0120 - val_loss: 0.0056
# Epoch 16/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0111 - val_loss: 0.0058
# Epoch 17/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0112 - val_loss: 0.0060
# Epoch 18/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0112 - val_loss: 0.0059
# Epoch 19/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0109 - val_loss: 0.0060
# Epoch 20/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0056
# Epoch 21/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0110 - val_loss: 0.0056
# Epoch 22/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0112 - val_loss: 0.0057
# Epoch 23/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0111 - val_loss: 0.0057
# Epoch 24/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0057
# Epoch 25/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0110 - val_loss: 0.0063
# Epoch 26/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0111 - val_loss: 0.0057
# Epoch 27/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0111 - val_loss: 0.0057
# Epoch 28/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0061
# Epoch 29/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0110 - val_loss: 0.0056
# Epoch 30/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0107 - val_loss: 0.0056
# Epoch 31/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0107 - val_loss: 0.0062
# Epoch 32/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0108 - val_loss: 0.0057
# Epoch 33/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0105 - val_loss: 0.0060
# Epoch 34/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0057
# Epoch 35/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0108 - val_loss: 0.0057
# Epoch 36/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0107 - val_loss: 0.0057
# Epoch 37/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0058
# Epoch 38/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0057
# Epoch 39/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0105 - val_loss: 0.0065
# Epoch 40/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0107 - val_loss: 0.0057
# Epoch 41/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0109 - val_loss: 0.0057
# Epoch 42/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0057
# Epoch 43/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0058
# Epoch 44/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0102 - val_loss: 0.0058
# Epoch 45/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0105 - val_loss: 0.0058
# Epoch 46/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0058
# Epoch 47/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0058
# Epoch 48/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0059
# Epoch 49/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0059
# Epoch 50/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0057
# Epoch 51/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0058
# Epoch 52/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0059
# Epoch 53/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 54/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0102 - val_loss: 0.0060
# Epoch 55/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0060
# Epoch 56/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0102 - val_loss: 0.0063
# Epoch 57/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0063
# Epoch 58/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0061
# Epoch 59/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0102 - val_loss: 0.0060
# Epoch 60/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0059
# Epoch 61/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0068
# Epoch 62/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0106 - val_loss: 0.0092
# Epoch 63/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0104 - val_loss: 0.0064
# Epoch 64/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0068
# Epoch 65/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0059
# Epoch 66/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0058
# Epoch 67/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0102 - val_loss: 0.0057
# Epoch 68/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0062
# Epoch 69/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 70/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 71/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0094 - val_loss: 0.0068
# Epoch 72/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0062
# Epoch 73/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 74/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0072
# Epoch 75/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0061
# Epoch 76/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0060
# Epoch 77/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0059
# Epoch 78/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 79/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0058
# Epoch 80/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0065
# Epoch 81/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0059
# Epoch 82/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0098 - val_loss: 0.0057
# Epoch 83/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0057
# Epoch 84/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0064
# Epoch 85/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0064
# Epoch 86/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0098 - val_loss: 0.0066
# Epoch 87/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0065
# Epoch 88/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0078
# Epoch 89/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0066
# Epoch 90/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0064
# Epoch 91/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0058
# Epoch 92/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0057
# Epoch 93/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0101 - val_loss: 0.0059
# Epoch 94/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0098 - val_loss: 0.0058
# Epoch 95/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0064
# Epoch 96/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0095 - val_loss: 0.0065
# Epoch 97/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0096 - val_loss: 0.0058
# Epoch 98/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 99/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0094 - val_loss: 0.0061
# Epoch 100/100
# 761/761 [==============================] - 1s 1ms/step - loss: 0.0095 - val_loss: 0.0060
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.067495        0.010166                -10
# 2018-11-26     0.012125        0.011239                  6
# 2018-11-27     0.115165        0.012427                 10
# 2018-11-28    -0.043945        0.012419                -10
# 2018-11-29    -0.039241        0.012424                -10
# 2018-11-30     0.049880        0.012220                 10
# 2018-12-01    -0.021435        0.011848                -10
# 2018-12-02    -0.066661        0.012033                -10
# 2018-12-03     0.014691        0.012064                  7
# 2018-12-04    -0.075123        0.012910                -10
# 2018-12-05    -0.109678        0.013515                -10
# 2018-12-06     0.035165        0.014724                 10
# 2018-12-07    -0.023181        0.015753                -10
# 2018-12-08     0.032590        0.016133                 10
# 2018-12-09    -0.039398        0.016033                -10
# 2018-12-10    -0.029217        0.015595                -10
# 2018-12-11     0.028052        0.014492                 10
# 2018-12-12    -0.045625        0.013065                -10
# 2018-12-13    -0.028823        0.012253                -10
# 2018-12-14     0.004410        0.011339                  2
# 2018-12-15     0.013291        0.010420                  6
# 2018-12-16     0.117695        0.008593                 10
# 2018-12-17     0.073345        0.008124                 10
# 2018-12-18    -0.017669        0.008417                 -8
# 2018-12-19     0.157011        0.008847                 10
# 2018-12-20    -0.060036        0.009584                -10
# 2018-12-21     0.081506        0.010243                 10
# 2018-12-22     0.111524        0.011007                 10
# 2018-12-23     0.070766        0.011755                 10
# 2018-12-24    -0.070136        0.012122                -10
# ...                 ...             ...                ...
# 2019-04-23    -0.078651        0.035244                -10
# 2019-04-24     0.022616        0.032625                 10
# 2019-04-25     0.012208        0.031365                  6
# 2019-04-26    -0.001958        0.031125                  0
# 2019-04-27    -0.008605        0.031088                 -4
# 2019-04-28     0.049142        0.029126                 10
# 2019-04-29    -0.018067        0.027985                 -9
# 2019-04-30    -0.000805        0.027066                  0
# 2019-05-01     0.043090        0.026332                 10
# 2019-05-02    -0.027520        0.020103                -10
# 2019-05-03     0.002017        0.016442                  1
# 2019-05-04     0.059534        0.015362                 10
# 2019-05-05    -0.029419        0.012770                -10
# 2019-05-06     0.016786        0.012887                  8
# 2019-05-07    -0.003267        0.015799                 -1
# 2019-05-08     0.009598        0.019839                  4
# 2019-05-09     0.115594        0.021800                 10
# 2019-05-10    -0.022345        0.024877                -10
# 2019-05-11     0.040874        0.027781                 10
# 2019-05-12     0.108921        0.030027                 10
# 2019-05-13     0.144962        0.031205                 10
# 2019-05-14     0.063666        0.031210                 10
# 2019-05-15    -0.074224        0.029535                -10
# 2019-05-16    -0.044437        0.026384                -10
# 2019-05-17     0.115148        0.023903                 10
# 2019-05-18    -0.033729        0.022671                -10
# 2019-05-19     0.011265        0.022092                  5
# 2019-05-20    -0.045030        0.022205                -10
# 2019-05-21     0.008790        0.020647                  4
# 2019-05-22     0.016327        0.019755                  8
#
#             real_y_predict_range
# Date
# 2018-11-25                     5
# 2018-11-26                     5
# 2018-11-27                     6
# 2018-11-28                     6
# 2018-11-29                     6
# 2018-11-30                     6
# 2018-12-01                     5
# 2018-12-02                     6
# 2018-12-03                     6
# 2018-12-04                     6
# 2018-12-05                     6
# 2018-12-06                     7
# 2018-12-07                     7
# 2018-12-08                     8
# 2018-12-09                     8
# 2018-12-10                     7
# 2018-12-11                     7
# 2018-12-12                     6
# 2018-12-13                     6
# 2018-12-14                     5
# 2018-12-15                     5
# 2018-12-16                     4
# 2018-12-17                     4
# 2018-12-18                     4
# 2018-12-19                     4
# 2018-12-20                     4
# 2018-12-21                     5
# 2018-12-22                     5
# 2018-12-23                     5
# 2018-12-24                     6
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                     8
# 2019-05-04                     7
# 2019-05-05                     6
# 2019-05-06                     6
# 2019-05-07                     7
# 2019-05-08                     9
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                    10
# 2019-05-17                    10
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    10
# 2019-05-22                     9
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.1389
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 1.056727261539883
# Annulized Sharpe Ratio for buy and hold strategy is 1.056727261539883

# %%
#Compile together
#LTC
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("merge_LTC-USD.csv", 30, 0.9063)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 32, 100, .3)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("LTC Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_LTC.csv')
# Out:
# (1740, 30, 108)
# (1740,)
# (180, 30, 108)
# (180,)
# 30
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 30, 32)            18048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30, 32)            8320
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 36,833
# Trainable params: 36,833
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1218 samples, validate on 522 samples
# Epoch 1/100
# 1218/1218 [==============================] - 4s 4ms/step - loss: 0.0160 - val_loss: 0.0018
# Epoch 2/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 3/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 4/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 5/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 6/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 7/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 8/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 9/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 10/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 11/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 12/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 13/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 14/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 15/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 16/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 17/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 18/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 19/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 20/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 21/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 22/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 23/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 24/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 25/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 26/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 27/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 28/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 29/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 30/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 31/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 32/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 33/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 34/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 35/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 36/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 37/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 38/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 39/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 40/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 41/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 42/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 43/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 44/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 45/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 46/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 47/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 48/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 49/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 50/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 51/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 52/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 53/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 54/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 55/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 56/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 57/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 58/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 59/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 60/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 61/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 62/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 63/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 64/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 65/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 66/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 67/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 68/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 69/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 70/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 71/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 72/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 73/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 74/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 75/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 76/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 77/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 78/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 79/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 80/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 81/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 82/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 83/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 84/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 85/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 86/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 87/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 88/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 89/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 90/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 91/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 92/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 93/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 94/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 95/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 96/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 97/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 98/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 99/100
# 1218/1218 [==============================] - 2s 1ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 100/100
# 1218/1218 [==============================] - 1s 1ms/step - loss: 0.0013 - val_loss: 0.0025
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.043450        0.109304                -10
# 2018-11-26     0.055254        0.109287                 10
# 2018-11-27     0.112432        0.109243                 10
# 2018-11-28    -0.027433        0.108971                -10
# 2018-11-29    -0.054335        0.108070                -10
# 2018-11-30     0.071272        0.106915                 10
# 2018-12-01    -0.015826        0.105906                 -7
# 2018-12-02    -0.085765        0.104547                -10
# 2018-12-03     0.008143        0.103068                  4
# 2018-12-04    -0.065590        0.101150                -10
# 2018-12-05    -0.082642        0.098673                -10
# 2018-12-06    -0.057671        0.095620                -10
# 2018-12-07    -0.020000        0.092760                 -9
# 2018-12-08     0.044898        0.091427                 10
# 2018-12-09    -0.051562        0.091069                -10
# 2018-12-10    -0.035008        0.090636                -10
# 2018-12-11     0.039693        0.090339                 10
# 2018-12-12    -0.051724        0.090507                -10
# 2018-12-13     0.011255        0.090627                  5
# 2018-12-14     0.014983        0.091002                  7
# 2018-12-15     0.081822        0.091204                 10
# 2018-12-16     0.142690        0.090944                 10
# 2018-12-17     0.038553        0.090390                 10
# 2018-12-18    -0.034494        0.089229                -10
# 2018-12-19     0.117047        0.087622                 10
# 2018-12-20    -0.069753        0.085276                -10
# 2018-12-21     0.052063        0.082328                 10
# 2018-12-22     0.042639        0.079363                 10
# 2018-12-23    -0.006567        0.076213                 -3
# 2018-12-24    -0.064904        0.073026                -10
# ...                 ...             ...                ...
# 2019-04-23    -0.031906        0.093742                -10
# 2019-04-24     0.025352        0.094927                 10
# 2019-04-25    -0.020467        0.095752                -10
# 2019-04-26    -0.030991        0.096417                -10
# 2019-04-27    -0.016787        0.097119                 -8
# 2019-04-28     0.105681        0.097880                 10
# 2019-04-29    -0.016906        0.098441                 -8
# 2019-04-30     0.000135        0.098402                  0
# 2019-05-01     0.073517        0.098557                 10
# 2019-05-02    -0.014630        0.098763                 -7
# 2019-05-03    -0.027390        0.098571                -10
# 2019-05-04    -0.006711        0.098560                 -3
# 2019-05-05    -0.015898        0.098664                 -7
# 2019-05-06     0.010366        0.098864                  5
# 2019-05-07    -0.013058        0.099000                 -6
# 2019-05-08     0.036857        0.098901                 10
# 2019-05-09     0.145833        0.099362                 10
# 2019-05-10    -0.036023        0.099774                -10
# 2019-05-11     0.033007        0.099830                 10
# 2019-05-12     0.044163        0.099556                 10
# 2019-05-13     0.116612        0.098872                 10
# 2019-05-14    -0.063717        0.097953                -10
# 2019-05-15    -0.059377        0.096855                -10
# 2019-05-16    -0.036341        0.096168                -10
# 2019-05-17     0.096298        0.096008                 10
# 2019-05-18    -0.035977        0.096461                -10
# 2019-05-19    -0.004365        0.096732                 -2
# 2019-05-20    -0.038470        0.097134                -10
# 2019-05-21     0.013222        0.098415                  6
# 2019-05-22     0.131061        0.099542                 10
#
#             real_y_predict_range
# Date
# 2018-11-25                    10
# 2018-11-26                    10
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                    10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                    10
# 2018-12-04                    10
# 2018-12-05                    10
# 2018-12-06                    10
# 2018-12-07                    10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                    10
# 2018-12-14                    10
# 2018-12-15                    10
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                    10
# 2018-12-20                    10
# 2018-12-21                    10
# 2018-12-22                    10
# 2018-12-23                    10
# 2018-12-24                    10
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                    10
# 2019-05-08                    10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                    10
# 2019-05-17                    10
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    10
# 2019-05-22                    10
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.3556
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 1.4936024962189969
# Annulized Sharpe Ratio for buy and hold strategy is 1.4936024962189969

# %%
#Compile together
#XRP
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("merge_XRP-USD.csv", 30, 0.8773)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 64, 100, .4)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("XRP Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_XRP.csv')
# Out:
# (1286, 30, 110)
# (1286,)
# (180, 30, 110)
# (180,)
# 30
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 30, 32)            18304
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 30, 32)            8320
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# dense_8 (Dense)              (None, 30, 32)            1056
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 37,089
# Trainable params: 37,089
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 771 samples, validate on 515 samples
# Epoch 1/100
# 771/771 [==============================] - 4s 5ms/step - loss: 0.0190 - val_loss: 0.0036
# Epoch 2/100
# 771/771 [==============================] - 1s 810us/step - loss: 0.0067 - val_loss: 0.0029
# Epoch 3/100
# 771/771 [==============================] - 1s 769us/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 4/100
# 771/771 [==============================] - 1s 814us/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 5/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 6/100
# 771/771 [==============================] - 1s 803us/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 7/100
# 771/771 [==============================] - 1s 806us/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 8/100
# 771/771 [==============================] - 1s 825us/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 9/100
# 771/771 [==============================] - 1s 784us/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 10/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 11/100
# 771/771 [==============================] - 1s 807us/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 12/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 13/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 14/100
# 771/771 [==============================] - 1s 798us/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 15/100
# 771/771 [==============================] - 1s 832us/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 16/100
# 771/771 [==============================] - 1s 803us/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 17/100
# 771/771 [==============================] - 1s 817us/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 18/100
# 771/771 [==============================] - 1s 831us/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 19/100
# 771/771 [==============================] - 1s 802us/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 20/100
# 771/771 [==============================] - 1s 813us/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 21/100
# 771/771 [==============================] - 1s 819us/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 22/100
# 771/771 [==============================] - 1s 801us/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 23/100
# 771/771 [==============================] - 1s 800us/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 24/100
# 771/771 [==============================] - 1s 822us/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 25/100
# 771/771 [==============================] - 1s 830us/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 26/100
# 771/771 [==============================] - 1s 826us/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 27/100
# 771/771 [==============================] - 1s 826us/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 28/100
# 771/771 [==============================] - 1s 788us/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 29/100
# 771/771 [==============================] - 1s 830us/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 30/100
# 771/771 [==============================] - 1s 810us/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 31/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 32/100
# 771/771 [==============================] - 1s 813us/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 33/100
# 771/771 [==============================] - 1s 791us/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 34/100
# 771/771 [==============================] - 1s 833us/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 35/100
# 771/771 [==============================] - 1s 800us/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 36/100
# 771/771 [==============================] - 1s 814us/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 37/100
# 771/771 [==============================] - 1s 805us/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 38/100
# 771/771 [==============================] - 1s 788us/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 39/100
# 771/771 [==============================] - 1s 766us/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 40/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 41/100
# 771/771 [==============================] - 1s 804us/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 42/100
# 771/771 [==============================] - 1s 798us/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 43/100
# 771/771 [==============================] - 1s 786us/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 44/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 45/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 46/100
# 771/771 [==============================] - 1s 796us/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 47/100
# 771/771 [==============================] - 1s 794us/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 48/100
# 771/771 [==============================] - 1s 795us/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 49/100
# 771/771 [==============================] - 1s 796us/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 50/100
# 771/771 [==============================] - 1s 803us/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 51/100
# 771/771 [==============================] - 1s 804us/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 52/100
# 771/771 [==============================] - 1s 777us/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 53/100
# 771/771 [==============================] - 1s 776us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 54/100
# 771/771 [==============================] - 1s 825us/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 55/100
# 771/771 [==============================] - 1s 792us/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 56/100
# 771/771 [==============================] - 1s 834us/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 57/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 58/100
# 771/771 [==============================] - 1s 791us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 59/100
# 771/771 [==============================] - 1s 809us/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 60/100
# 771/771 [==============================] - 1s 820us/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 61/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 62/100
# 771/771 [==============================] - 1s 816us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 63/100
# 771/771 [==============================] - 1s 810us/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 64/100
# 771/771 [==============================] - 1s 805us/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 65/100
# 771/771 [==============================] - 1s 797us/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 66/100
# 771/771 [==============================] - 1s 809us/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 67/100
# 771/771 [==============================] - 1s 795us/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 68/100
# 771/771 [==============================] - 1s 797us/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 69/100
# 771/771 [==============================] - 1s 835us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 70/100
# 771/771 [==============================] - 1s 800us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 71/100
# 771/771 [==============================] - 1s 804us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 72/100
# 771/771 [==============================] - 1s 808us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 73/100
# 771/771 [==============================] - 1s 806us/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 74/100
# 771/771 [==============================] - 1s 803us/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 75/100
# 771/771 [==============================] - 1s 879us/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 76/100
# 771/771 [==============================] - 1s 814us/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 77/100
# 771/771 [==============================] - 1s 837us/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 78/100
# 771/771 [==============================] - 1s 807us/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 79/100
# 771/771 [==============================] - 1s 811us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 80/100
# 771/771 [==============================] - 1s 790us/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 81/100
# 771/771 [==============================] - 1s 804us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 82/100
# 771/771 [==============================] - 1s 805us/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 83/100
# 771/771 [==============================] - 1s 784us/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 84/100
# 771/771 [==============================] - 1s 818us/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 85/100
# 771/771 [==============================] - 1s 792us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 86/100
# 771/771 [==============================] - 1s 819us/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 87/100
# 771/771 [==============================] - 1s 792us/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 88/100
# 771/771 [==============================] - 1s 787us/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 89/100
# 771/771 [==============================] - 1s 804us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 90/100
# 771/771 [==============================] - 1s 784us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 91/100
# 771/771 [==============================] - 1s 800us/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 92/100
# 771/771 [==============================] - 1s 788us/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 93/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 94/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 95/100
# 771/771 [==============================] - 1s 802us/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 96/100
# 771/771 [==============================] - 1s 795us/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 97/100
# 771/771 [==============================] - 1s 787us/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 98/100
# 771/771 [==============================] - 1s 811us/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 99/100
# 771/771 [==============================] - 1s 792us/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 100/100
# 771/771 [==============================] - 1s 799us/step - loss: 0.0037 - val_loss: 0.0014
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.050767       -0.006966                -10
# 2018-11-26     0.010028       -0.007691                  5
# 2018-11-27     0.082460       -0.008468                 10
# 2018-11-28    -0.028790       -0.008663                -10
# 2018-11-29    -0.047744       -0.009221                -10
# 2018-11-30     0.029477       -0.009729                 10
# 2018-12-01    -0.011239       -0.009974                 -5
# 2018-12-02    -0.061434       -0.009870                -10
# 2018-12-03     0.014706       -0.009027                  7
# 2018-12-04    -0.042342       -0.008023                -10
# 2018-12-05    -0.087834       -0.006430                -10
# 2018-12-06    -0.016591       -0.004564                 -8
# 2018-12-07     0.016871       -0.002827                  8
# 2018-12-08     0.020169       -0.001374                 10
# 2018-12-09    -0.036352        0.000247                -10
# 2018-12-10    -0.005625        0.001432                 -2
# 2018-12-11     0.025291        0.002312                 10
# 2018-12-12    -0.025641        0.001896                -10
# 2018-12-13    -0.035976        0.001263                -10
# 2018-12-14    -0.012440        0.001002                 -6
# 2018-12-15     0.011546        0.000645                  5
# 2018-12-16     0.148046        0.000384                 10
# 2018-12-17     0.072010       -0.000020                 10
# 2018-12-18    -0.007589       -0.001352                 -3
# 2018-12-19     0.078448       -0.003285                 10
# 2018-12-20    -0.052258       -0.005616                -10
# 2018-12-21     0.018288       -0.007753                  9
# 2018-12-22     0.022313       -0.009278                 10
# 2018-12-23     0.090498       -0.009851                 10
# 2018-12-24    -0.057359       -0.010262                -10
# ...                 ...             ...                ...
# 2019-04-23    -0.045741       -0.008437                -10
# 2019-04-24     0.043071       -0.008739                 10
# 2019-04-25    -0.016983       -0.008762                 -8
# 2019-04-26     0.010501       -0.008209                  5
# 2019-04-27    -0.009051       -0.007271                 -4
# 2019-04-28     0.053112       -0.006664                 10
# 2019-04-29    -0.018632       -0.006067                 -9
# 2019-04-30    -0.007856       -0.005821                 -3
# 2019-05-01     0.014517       -0.005740                  7
# 2019-05-02    -0.008780       -0.005703                 -4
# 2019-05-03    -0.012795       -0.005989                 -6
# 2019-05-04     0.009970       -0.006414                  4
# 2019-05-05    -0.021060       -0.006708                -10
# 2019-05-06     0.009076       -0.006968                  4
# 2019-05-07    -0.017988       -0.007388                 -8
# 2019-05-08     0.012212       -0.007783                  6
# 2019-05-09     0.077748       -0.007689                 10
# 2019-05-10    -0.033893       -0.006719                -10
# 2019-05-11     0.042807       -0.005468                 10
# 2019-05-12     0.257716       -0.004160                 10
# 2019-05-13     0.123681       -0.003385                 10
# 2019-05-14    -0.084953       -0.003311                -10
# 2019-05-15    -0.068735       -0.002553                -10
# 2019-05-16    -0.046899       -0.001987                -10
# 2019-05-17     0.125303       -0.001780                 10
# 2019-05-18    -0.045878       -0.001715                -10
# 2019-05-19    -0.005510       -0.001654                 -2
# 2019-05-20    -0.063964       -0.001738                -10
# 2019-05-21     0.024213       -0.000926                 10
# 2019-05-22     0.008668        0.000103                  4
#
#             real_y_predict_range
# Date
# 2018-11-25                    -3
# 2018-11-26                    -3
# 2018-11-27                    -4
# 2018-11-28                    -4
# 2018-11-29                    -4
# 2018-11-30                    -4
# 2018-12-01                    -4
# 2018-12-02                    -4
# 2018-12-03                    -4
# 2018-12-04                    -4
# 2018-12-05                    -3
# 2018-12-06                    -2
# 2018-12-07                    -1
# 2018-12-08                     0
# 2018-12-09                     0
# 2018-12-10                     0
# 2018-12-11                     1
# 2018-12-12                     0
# 2018-12-13                     0
# 2018-12-14                     0
# 2018-12-15                     0
# 2018-12-16                     0
# 2018-12-17                     0
# 2018-12-18                     0
# 2018-12-19                    -1
# 2018-12-20                    -2
# 2018-12-21                    -3
# 2018-12-22                    -4
# 2018-12-23                    -4
# 2018-12-24                    -5
# ...                          ...
# 2019-04-23                    -4
# 2019-04-24                    -4
# 2019-04-25                    -4
# 2019-04-26                    -4
# 2019-04-27                    -3
# 2019-04-28                    -3
# 2019-04-29                    -3
# 2019-04-30                    -2
# 2019-05-01                    -2
# 2019-05-02                    -2
# 2019-05-03                    -2
# 2019-05-04                    -3
# 2019-05-05                    -3
# 2019-05-06                    -3
# 2019-05-07                    -3
# 2019-05-08                    -3
# 2019-05-09                    -3
# 2019-05-10                    -3
# 2019-05-11                    -2
# 2019-05-12                    -2
# 2019-05-13                    -1
# 2019-05-14                    -1
# 2019-05-15                    -1
# 2019-05-16                     0
# 2019-05-17                     0
# 2019-05-18                     0
# 2019-05-19                     0
# 2019-05-20                     0
# 2019-05-21                     0
# 2019-05-22                     0
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.0333
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 0.2630776687991308
# Annulized Sharpe Ratio for buy and hold strategy is -0.32246454698985777

# %%
#Compile together
#ZEC
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("merge_ZEC-USD.csv", 30, 0.7808)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 32, 100, .3)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("ZEC Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_ZEC.csv')
# Out:
# (640, 30, 112)
# (640,)
# (180, 30, 112)
# (180,)
# 30
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 30, 32)            18560
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 30, 32)            8320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_11 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 37,345
# Trainable params: 37,345
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 448 samples, validate on 192 samples
# Epoch 1/100
# 448/448 [==============================] - 4s 8ms/step - loss: 0.0225 - val_loss: 0.0066
# Epoch 2/100
# 448/448 [==============================] - 0s 1ms/step - loss: 0.0106 - val_loss: 0.0033
# Epoch 3/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 4/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0103 - val_loss: 0.0033
# Epoch 5/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0093 - val_loss: 0.0033
# Epoch 6/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0088 - val_loss: 0.0033
# Epoch 7/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0094 - val_loss: 0.0046
# Epoch 8/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0099 - val_loss: 0.0034
# Epoch 9/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0091 - val_loss: 0.0037
# Epoch 10/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0094 - val_loss: 0.0034
# Epoch 11/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0091 - val_loss: 0.0035
# Epoch 12/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0085 - val_loss: 0.0035
# Epoch 13/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0084 - val_loss: 0.0033
# Epoch 14/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0088 - val_loss: 0.0033
# Epoch 15/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0083 - val_loss: 0.0033
# Epoch 16/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0036
# Epoch 17/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0087 - val_loss: 0.0033
# Epoch 18/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0085 - val_loss: 0.0033
# Epoch 19/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0088 - val_loss: 0.0033
# Epoch 20/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0084 - val_loss: 0.0033
# Epoch 21/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0086 - val_loss: 0.0040
# Epoch 22/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0085 - val_loss: 0.0033
# Epoch 23/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0082 - val_loss: 0.0038
# Epoch 24/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0034
# Epoch 25/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0084 - val_loss: 0.0033
# Epoch 26/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0082 - val_loss: 0.0033
# Epoch 27/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0087 - val_loss: 0.0036
# Epoch 28/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0086 - val_loss: 0.0032
# Epoch 29/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0037
# Epoch 30/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0032
# Epoch 31/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0033
# Epoch 32/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0035
# Epoch 33/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0032
# Epoch 34/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 35/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0082 - val_loss: 0.0033
# Epoch 36/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 37/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 38/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0082 - val_loss: 0.0033
# Epoch 39/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 40/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0033
# Epoch 41/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0078 - val_loss: 0.0033
# Epoch 42/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0082 - val_loss: 0.0037
# Epoch 43/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0083 - val_loss: 0.0040
# Epoch 44/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0033
# Epoch 45/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 46/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0033
# Epoch 47/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0038
# Epoch 48/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 49/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 50/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0032
# Epoch 51/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0032
# Epoch 52/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 53/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0032
# Epoch 54/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0035
# Epoch 55/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0086 - val_loss: 0.0035
# Epoch 56/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 57/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0032
# Epoch 58/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0079 - val_loss: 0.0035
# Epoch 59/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 60/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 61/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 62/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0079 - val_loss: 0.0033
# Epoch 63/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0038
# Epoch 64/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0034
# Epoch 65/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 66/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0035
# Epoch 67/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0033
# Epoch 68/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0034
# Epoch 69/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0076 - val_loss: 0.0034
# Epoch 70/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0033
# Epoch 71/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0035
# Epoch 72/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0042
# Epoch 73/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 74/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0037
# Epoch 75/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0083 - val_loss: 0.0033
# Epoch 76/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0049
# Epoch 77/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 78/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0034
# Epoch 79/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0035
# Epoch 80/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.0035
# Epoch 81/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0077 - val_loss: 0.0035
# Epoch 82/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0039
# Epoch 83/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 84/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0035
# Epoch 85/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.0038
# Epoch 86/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 87/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0037
# Epoch 88/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 89/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.0035
# Epoch 90/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0071 - val_loss: 0.0038
# Epoch 91/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0034
# Epoch 92/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 93/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0071 - val_loss: 0.0051
# Epoch 94/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0073 - val_loss: 0.0036
# Epoch 95/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0047
# Epoch 96/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0071 - val_loss: 0.0040
# Epoch 97/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0070 - val_loss: 0.0035
# Epoch 98/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.0041
# Epoch 99/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0034
# Epoch 100/100
# 448/448 [==============================] - 1s 1ms/step - loss: 0.0072 - val_loss: 0.0039
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.058028        0.033558                -10
# 2018-11-26     0.094647        0.033255                 10
# 2018-11-27     0.094796        0.036799                 10
# 2018-11-28     0.101435        0.040604                 10
# 2018-11-29    -0.081898        0.042313                -10
# 2018-11-30    -0.003578        0.041173                 -1
# 2018-12-01    -0.011763        0.038751                 -5
# 2018-12-02    -0.111014        0.030115                -10
# 2018-12-03     0.052290        0.019895                 10
# 2018-12-04    -0.115457        0.015412                -10
# 2018-12-05    -0.119473        0.014907                -10
# 2018-12-06     0.029063        0.017994                 10
# 2018-12-07    -0.037935        0.024108                -10
# 2018-12-08     0.056453        0.026521                 10
# 2018-12-09    -0.067905        0.029297                -10
# 2018-12-10    -0.047627        0.031579                -10
# 2018-12-11     0.028524        0.034218                 10
# 2018-12-12    -0.069692        0.037701                -10
# 2018-12-13    -0.043167        0.040284                -10
# 2018-12-14     0.022861        0.042704                 10
# 2018-12-15     0.020767        0.045368                 10
# 2018-12-16     0.108312        0.047299                 10
# 2018-12-17     0.039336        0.046110                 10
# 2018-12-18    -0.025736        0.042041                -10
# 2018-12-19     0.148135        0.035850                 10
# 2018-12-20    -0.063609        0.029734                -10
# 2018-12-21     0.038702        0.023014                 10
# 2018-12-22     0.022727        0.017204                 10
# 2018-12-23     0.043386        0.011468                 10
# 2018-12-24    -0.095769        0.004894                -10
# ...                 ...             ...                ...
# 2019-04-23    -0.067995        0.079095                -10
# 2019-04-24     0.026114        0.092735                 10
# 2019-04-25    -0.031175        0.106083                -10
# 2019-04-26     0.012149        0.115146                  6
# 2019-04-27    -0.050608        0.119712                -10
# 2019-04-28     0.067145        0.119022                 10
# 2019-04-29    -0.023695        0.115603                -10
# 2019-04-30     0.008035        0.108121                  4
# 2019-05-01     0.042622        0.098080                 10
# 2019-05-02    -0.025433        0.087217                -10
# 2019-05-03    -0.012808        0.075403                 -6
# 2019-05-04    -0.006974        0.064453                 -3
# 2019-05-05    -0.050139        0.055705                -10
# 2019-05-06     0.012724        0.044134                  6
# 2019-05-07    -0.028353        0.039316                -10
# 2019-05-08     0.013280        0.040176                  6
# 2019-05-09     0.097775        0.045088                 10
# 2019-05-10    -0.048539        0.051694                -10
# 2019-05-11     0.048209        0.054474                 10
# 2019-05-12     0.065837        0.054459                 10
# 2019-05-13     0.135954        0.050078                 10
# 2019-05-14    -0.026018        0.041662                -10
# 2019-05-15    -0.014826        0.028107                 -7
# 2019-05-16    -0.025353        0.014178                -10
# 2019-05-17     0.084156        0.004030                 10
# 2019-05-18    -0.019502       -0.001518                 -9
# 2019-05-19    -0.020152       -0.005399                -10
# 2019-05-20    -0.063835       -0.007269                -10
# 2019-05-21     0.025107       -0.006953                 10
# 2019-05-22     0.009741       -0.003742                  4
#
#             real_y_predict_range
# Date
# 2018-11-25                    10
# 2018-11-26                    10
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                    10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                     9
# 2018-12-04                     7
# 2018-12-05                     7
# 2018-12-06                     8
# 2018-12-07                    10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                    10
# 2018-12-14                    10
# 2018-12-15                    10
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                    10
# 2018-12-20                    10
# 2018-12-21                    10
# 2018-12-22                     8
# 2018-12-23                     5
# 2018-12-24                     2
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                    10
# 2019-05-08                    10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                     7
# 2019-05-17                     2
# 2019-05-18                     0
# 2019-05-19                    -2
# 2019-05-20                    -3
# 2019-05-21                    -3
# 2019-05-22                    -1
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.2056
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 0.19584551163407285
# Annulized Sharpe Ratio for buy and hold strategy is -0.2905846972302419

# %%
#Compile together
#Bitcoin
#load the data 
X_train, Y_train, X_test, Y_test, window_length, dataset_total,Y_daybefore,line= load_data("Bitcoin.csv", 30, 0.9422)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)
print(window_length)
print(Y_daybefore.shape)

#initialize the model
model = initialize_model(0.3)
print (model.summary())

#fit the model
model = fit_model(model, X_train, Y_train, 32, 100, .2)


#test the model and compare predicted return with real return
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model, X_test, Y_test)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)

print("Successful prediction rate is "+str(successful_rate))

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("Bitcoin Skeleton Layer Model Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_skeleton_Bit.csv')
# Out:
# (2934, 30, 105)
# (2934,)
# (180, 30, 105)
# (180,)
# 30
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 30, 32)            17664
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_13 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 30, 32)            8320
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# dense_14 (Dense)             (None, 30, 32)            1056
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 36,449
# Trainable params: 36,449
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 2347 samples, validate on 587 samples
# Epoch 1/100
# 2347/2347 [==============================] - 11s 5ms/step - loss: 0.0016 - val_loss: 5.6179e-04
# Epoch 2/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 9.4521e-04 - val_loss: 2.9275e-04
# Epoch 3/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 8.6824e-04 - val_loss: 4.7101e-04
# Epoch 4/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 7.9669e-04 - val_loss: 2.2628e-04
# Epoch 5/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 7.5905e-04 - val_loss: 1.7624e-04
# Epoch 6/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.9133e-04 - val_loss: 1.5757e-04
# Epoch 7/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.7414e-04 - val_loss: 2.0574e-04
# Epoch 8/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.6644e-04 - val_loss: 1.9683e-04
# Epoch 9/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.6170e-04 - val_loss: 1.8865e-04
# Epoch 10/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.5352e-04 - val_loss: 2.1666e-04
# Epoch 11/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.2319e-04 - val_loss: 1.7283e-04
# Epoch 12/100
# 2347/2347 [==============================] - 5s 2ms/step - loss: 6.1340e-04 - val_loss: 1.9854e-04
# Epoch 13/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.1336e-04 - val_loss: 1.5659e-04
# Epoch 14/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.0321e-04 - val_loss: 1.7207e-04
# Epoch 15/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.0845e-04 - val_loss: 2.4515e-04
# Epoch 16/100
# 2347/2347 [==============================] - 4s 2ms/step - loss: 6.0482e-04 - val_loss: 1.7559e-04
# Epoch 17/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9946e-04 - val_loss: 1.6608e-04
# Epoch 18/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.1536e-04 - val_loss: 1.6392e-04
# Epoch 19/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9734e-04 - val_loss: 1.7730e-04
# Epoch 20/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9645e-04 - val_loss: 2.0474e-04
# Epoch 21/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9398e-04 - val_loss: 1.7855e-04
# Epoch 22/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8314e-04 - val_loss: 3.9224e-04
# Epoch 23/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.1558e-04 - val_loss: 1.7658e-04
# Epoch 24/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8435e-04 - val_loss: 3.4226e-04
# Epoch 25/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9157e-04 - val_loss: 3.7010e-04
# Epoch 26/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9912e-04 - val_loss: 3.1316e-04
# Epoch 27/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9111e-04 - val_loss: 2.8628e-04
# Epoch 28/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8388e-04 - val_loss: 3.0909e-04
# Epoch 29/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9110e-04 - val_loss: 2.7261e-04
# Epoch 30/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9531e-04 - val_loss: 3.0413e-04
# Epoch 31/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7845e-04 - val_loss: 7.0350e-04
# Epoch 32/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6530e-04 - val_loss: 2.0811e-04
# Epoch 33/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.0065e-04 - val_loss: 2.2946e-04
# Epoch 34/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8930e-04 - val_loss: 0.0013
# Epoch 35/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.0525e-04 - val_loss: 5.0819e-04
# Epoch 36/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9328e-04 - val_loss: 2.6493e-04
# Epoch 37/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8235e-04 - val_loss: 3.1582e-04
# Epoch 38/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9836e-04 - val_loss: 3.6235e-04
# Epoch 39/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.0738e-04 - val_loss: 1.4793e-04
# Epoch 40/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.0588e-04 - val_loss: 1.5974e-04
# Epoch 41/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8916e-04 - val_loss: 1.6252e-04
# Epoch 42/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9266e-04 - val_loss: 1.7825e-04
# Epoch 43/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9005e-04 - val_loss: 2.9592e-04
# Epoch 44/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7370e-04 - val_loss: 2.7082e-04
# Epoch 45/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7780e-04 - val_loss: 2.3268e-04
# Epoch 46/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7664e-04 - val_loss: 0.0017
# Epoch 47/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 6.0225e-04 - val_loss: 5.8717e-04
# Epoch 48/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9253e-04 - val_loss: 1.9021e-04
# Epoch 49/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9001e-04 - val_loss: 2.6098e-04
# Epoch 50/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8747e-04 - val_loss: 4.2037e-04
# Epoch 51/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8307e-04 - val_loss: 4.2313e-04
# Epoch 52/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8264e-04 - val_loss: 2.5174e-04
# Epoch 53/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6745e-04 - val_loss: 6.1581e-04
# Epoch 54/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8823e-04 - val_loss: 1.9157e-04
# Epoch 55/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8769e-04 - val_loss: 3.2531e-04
# Epoch 56/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7493e-04 - val_loss: 2.3023e-04
# Epoch 57/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9784e-04 - val_loss: 2.4240e-04
# Epoch 58/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8312e-04 - val_loss: 3.9369e-04
# Epoch 59/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8147e-04 - val_loss: 2.8510e-04
# Epoch 60/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8373e-04 - val_loss: 2.3869e-04
# Epoch 61/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8334e-04 - val_loss: 2.8069e-04
# Epoch 62/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7904e-04 - val_loss: 3.9232e-04
# Epoch 63/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.4910e-04 - val_loss: 4.1387e-04
# Epoch 64/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6334e-04 - val_loss: 2.1511e-04
# Epoch 65/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8299e-04 - val_loss: 1.7956e-04
# Epoch 66/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9602e-04 - val_loss: 1.5041e-04
# Epoch 67/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8499e-04 - val_loss: 1.4842e-04
# Epoch 68/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7589e-04 - val_loss: 2.3032e-04
# Epoch 69/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7871e-04 - val_loss: 1.9394e-04
# Epoch 70/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8426e-04 - val_loss: 1.8613e-04
# Epoch 71/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7150e-04 - val_loss: 2.8909e-04
# Epoch 72/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.7230e-04 - val_loss: 2.3939e-04
# Epoch 73/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.5452e-04 - val_loss: 5.4764e-04
# Epoch 74/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9141e-04 - val_loss: 2.4687e-04
# Epoch 75/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6433e-04 - val_loss: 1.5529e-04
# Epoch 76/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9881e-04 - val_loss: 2.1819e-04
# Epoch 77/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.5223e-04 - val_loss: 3.8626e-04
# Epoch 78/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.5776e-04 - val_loss: 1.5022e-04
# Epoch 79/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9299e-04 - val_loss: 1.4981e-04
# Epoch 80/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9314e-04 - val_loss: 1.4919e-04
# Epoch 81/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9148e-04 - val_loss: 1.4913e-04
# Epoch 82/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6969e-04 - val_loss: 1.9705e-04
# Epoch 83/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8694e-04 - val_loss: 1.4977e-04
# Epoch 84/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9705e-04 - val_loss: 1.6102e-04
# Epoch 85/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9389e-04 - val_loss: 1.5738e-04
# Epoch 86/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9178e-04 - val_loss: 1.4942e-04
# Epoch 87/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8591e-04 - val_loss: 1.4857e-04
# Epoch 88/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9389e-04 - val_loss: 1.4959e-04
# Epoch 89/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9182e-04 - val_loss: 1.4850e-04
# Epoch 90/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8558e-04 - val_loss: 1.7085e-04
# Epoch 91/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8138e-04 - val_loss: 1.5066e-04
# Epoch 92/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.6537e-04 - val_loss: 1.4860e-04
# Epoch 93/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.9404e-04 - val_loss: 1.4842e-04
# Epoch 94/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8785e-04 - val_loss: 1.5679e-04
# Epoch 95/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8624e-04 - val_loss: 1.4860e-04
# Epoch 96/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8905e-04 - val_loss: 1.4850e-04
# Epoch 97/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8842e-04 - val_loss: 1.5238e-04
# Epoch 98/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8866e-04 - val_loss: 1.5785e-04
# Epoch 99/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8968e-04 - val_loss: 1.4855e-04
# Epoch 100/100
# 2347/2347 [==============================] - 3s 1ms/step - loss: 5.8793e-04 - val_loss: 1.4855e-04
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-24     0.038930        0.002903                 10
# 2018-11-25    -0.054833        0.002903                -10
# 2018-11-26     0.010146        0.002903                  5
# 2018-11-27     0.115240        0.002903                 10
# 2018-11-28     0.005427        0.002903                  2
# 2018-11-29    -0.064623        0.002903                -10
# 2018-11-30     0.046834        0.002903                 10
# 2018-12-01    -0.012770        0.002903                 -6
# 2018-12-02    -0.065748        0.002903                -10
# 2018-12-03     0.019897        0.002903                  9
# 2018-12-04    -0.053416        0.002903                -10
# 2018-12-05    -0.067518        0.002903                -10
# 2018-12-06    -0.018538        0.002903                 -9
# 2018-12-07     0.011840        0.002903                  5
# 2018-12-08     0.038072        0.002903                 10
# 2018-12-09    -0.034981        0.002903                -10
# 2018-12-10    -0.019076        0.002903                 -9
# 2018-12-11     0.024866        0.002903                 10
# 2018-12-12    -0.051779        0.002903                -10
# 2018-12-13    -0.021067        0.002903                -10
# 2018-12-14    -0.000918        0.002903                  0
# 2018-12-15     0.007072        0.002903                  3
# 2018-12-16     0.089950        0.002903                 10
# 2018-12-17     0.047252        0.002903                 10
# 2018-12-18     0.005568        0.002903                  2
# 2018-12-19     0.107351        0.002903                 10
# 2018-12-20    -0.057726        0.002903                -10
# 2018-12-21     0.037558        0.002903                 10
# 2018-12-22    -0.009297        0.002903                 -4
# 2018-12-23     0.018545        0.002903                  9
# ...                 ...             ...                ...
# 2019-04-22    -0.015259        0.002903                 -7
# 2019-04-23    -0.053517        0.002903                -10
# 2019-04-24     0.013834        0.002903                  6
# 2019-04-25    -0.000881        0.002903                  0
# 2019-04-26     0.008217        0.002903                  4
# 2019-04-27    -0.006542        0.002903                 -3
# 2019-04-28     0.021512        0.002903                 10
# 2019-04-29     0.007270        0.002903                  3
# 2019-04-30     0.020629        0.002903                 10
# 2019-05-01     0.045932        0.002903                 10
# 2019-05-02     0.015069        0.002903                  7
# 2019-05-03    -0.007866        0.002903                 -3
# 2019-05-04    -0.007934        0.002903                 -3
# 2019-05-05     0.012421        0.002903                  6
# 2019-05-06     0.030782        0.002903                 10
# 2019-05-07     0.028881        0.002903                 10
# 2019-05-08     0.030190        0.002903                 10
# 2019-05-09     0.131021        0.002903                 10
# 2019-05-10    -0.029720        0.002903                -10
# 2019-05-11     0.118770        0.002903                 10
# 2019-05-12     0.022260        0.002903                 10
# 2019-05-13     0.025526        0.002903                 10
# 2019-05-14    -0.037845        0.002903                -10
# 2019-05-15    -0.063772        0.002903                -10
# 2019-05-16    -0.014363        0.002903                 -7
# 2019-05-17     0.127587        0.002903                 10
# 2019-05-18    -0.023782        0.002903                -10
# 2019-05-19    -0.006296        0.002903                 -3
# 2019-05-20    -0.040393        0.002903                -10
# 2019-05-21     0.033499        0.002903                 10
#
#             real_y_predict_range
# Date
# 2018-11-24                     1
# 2018-11-25                     1
# 2018-11-26                     1
# 2018-11-27                     1
# 2018-11-28                     1
# 2018-11-29                     1
# 2018-11-30                     1
# 2018-12-01                     1
# 2018-12-02                     1
# 2018-12-03                     1
# 2018-12-04                     1
# 2018-12-05                     1
# 2018-12-06                     1
# 2018-12-07                     1
# 2018-12-08                     1
# 2018-12-09                     1
# 2018-12-10                     1
# 2018-12-11                     1
# 2018-12-12                     1
# 2018-12-13                     1
# 2018-12-14                     1
# 2018-12-15                     1
# 2018-12-16                     1
# 2018-12-17                     1
# 2018-12-18                     1
# 2018-12-19                     1
# 2018-12-20                     1
# 2018-12-21                     1
# 2018-12-22                     1
# 2018-12-23                     1
# ...                          ...
# 2019-04-22                     1
# 2019-04-23                     1
# 2019-04-24                     1
# 2019-04-25                     1
# 2019-04-26                     1
# 2019-04-27                     1
# 2019-04-28                     1
# 2019-04-29                     1
# 2019-04-30                     1
# 2019-05-01                     1
# 2019-05-02                     1
# 2019-05-03                     1
# 2019-05-04                     1
# 2019-05-05                     1
# 2019-05-06                     1
# 2019-05-07                     1
# 2019-05-08                     1
# 2019-05-09                     1
# 2019-05-10                     1
# 2019-05-11                     1
# 2019-05-12                     1
# 2019-05-13                     1
# 2019-05-14                     1
# 2019-05-15                     1
# 2019-05-16                     1
# 2019-05-17                     1
# 2019-05-18                     1
# 2019-05-19                     1
# 2019-05-20                     1
# 2019-05-21                     1
#
# [180 rows x 4 columns]
# Successful prediction rate is 0.0389
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 1.0620883732767286
# Annulized Sharpe Ratio for buy and hold strategy is 1.0620883732767286

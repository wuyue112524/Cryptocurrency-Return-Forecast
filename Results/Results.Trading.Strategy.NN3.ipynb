# %%
## Keras for deep learning
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional
from keras.models import Sequential

## Scikit learn for mapping metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#for logging
import time

##matrix math
import math

##plotting
import matplotlib.pyplot as plt
from sklearn import preprocessing

import pandas as pd
import os
import numpy as np
import time
import datetime

##matrix math
import math


os.chdir('D:/Graduate Courses/2019 Dissertation/Data/Other.coins')
print("Current Working Directory " , os.getcwd())
# Out:
# Using TensorFlow backend.
# Current Working Directory  D:\Graduate Courses\2019 Dissertation\Data\Other.coins

# %%
# %load NN3
#!/usr/bin/env python

# In[1]:


import numpy as np
import talib
import pandas as pd
import os
import talib as ta
import time
import datetime

## Keras for deep learning
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional
from keras.models import Sequential

## Scikit learn for mapping metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#for logging
import time

##matrix math
import math

##plotting
import matplotlib.pyplot as plt
from sklearn import preprocessing


# In[1]:


def load_data(filename,percent):
#Read the data file
    dataset_total = pd.read_csv(filename,na_values='n/a',parse_dates=['Date'],index_col='Date')
    dataset_total=dataset_total.drop(['Unnamed: 0',], axis=1)
    dataset_total= dataset_total.loc[:, (dataset_total!= 0).any(axis=0)]

    #normalize dataset
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range = (0, 1))
    dataset_total_scaled = sc.fit_transform(dataset_total)
    X_normal=dataset_total_scaled[:,:-1]
    Y=dataset_total_scaled[:,-1]
    
    #Splitting data set into training (First 80% of data points) and testing data (last 20% of data points)
    split_line = round(percent * X_normal.shape[0])
    X_train = X_normal[:int(split_line), :]
    Y_train = Y[:int(split_line)]
    X_test = X_normal[int(split_line):,:]
    Y_test = Y[int(split_line):]
    Y_daybefore = Y[int(split_line)-1:-1]
  
    line=int(split_line)
    #shuffle the training set and test set
    #X_train, X_test, Y_train, Y_test = train_test_split(X_normal, Y, test_size=0.2, random_state=37)
    return X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line


# In[2]:


def initialize_model(dropout_rate):
    """
    Initializes and creates the model to be used
    
    Arguments:
    dropout_rate -- A decimal representing how much dropout should be incorporated at each level, in this case 0.2
    activation_function -- A string to define the activation_function, in this case it is linear
    loss_function -- A string to define the loss function to be used, in the case it is mean squared error
    optimizer -- A string to define the optimizer to be used, in the case it is adam
    
    Returns:
    model -- A 3 layer RNN with 100*dropout_value dropout in each layer that uses activation_function as its activation
             function, loss_function as its loss function, and optimizer as its optimizer
    """
  
    #Build the model
    model=Sequential()
    
   
    optimizer='adam'
    loss='mean_squared_error'
    activation='relu'
    input_shape = (X_train.shape[1],)
    model.add(Dense(units = 64,activation=activation, input_shape = input_shape))
    model.add(Dense(units = 64, activation=activation))
    model.add(Dense(units = 32, activation=activation))
    model.add(Dense(units = 1,activation='relu'))
   
    
              
    model.compile(optimizer =optimizer, loss = loss, metrics=['mse'])

    
    return model


# In[3]:


#Training the model

def fit_model(model, X_train, Y_train, batch_num, num_epoch, val_split):
    """
    Fits the model to the training data
    
    Arguments:
    model -- The previously initalized 3 layer Recurrent Neural Network
    X_train -- A tensor of shape (2492, 30, 105) that represents the x values of the training data
    Y_train -- A tensor of shape (2492,) that represents the y values of the training data
    batch_num -- An integer representing the batch size to be used, in this case 100
    num_epoch -- An integer defining the number of epochs to be run, in this case 100
    val_split -- A decimal representing the proportion of training data to be used as validation data
    
    Returns:
    model -- The 3 layer Recurrent Neural Network that has been fitted to the training data
    training_time -- An integer representing the amount of time (in seconds) that the model was training
    """
   

    #Train the model on X_train and Y_train
    history=model.fit(X_train, Y_train, batch_size= batch_num, nb_epoch=num_epoch, validation_split= val_split)

    return model,history


# In[5]:





# In[4]:


# test the model
def test_model(model_name, X_test, Y_test):
    """
    Test the model on the testing data
    
    Arguments:
    model -- The previously fitted 3 layer Recurrent Neural Network
    X_test -- A tensor of shape (623, 30, 105) that represents the x values of the testing data
    Y_test -- A tensor of shape (623,) that represents the y values of the testing data
    unnormalized_bases -- A tensor of shape (623,) that can be used to get unnormalized data points
    
    Returns:
    y_predict -- A tensor of shape (623,) that represnts the normalized values that the model predicts based on X_test
    real_y_test -- A tensor of shape (623,) that represents the actual prices of bitcoin throughout the testing period
    real_y_predict -- A tensor of shape (623,) that represents the model's predicted prices of bitcoin
    fig -- A branch of the graph of the real predicted prices of bitcoin versus the real prices of bitcoin
    """
    #Test the model on X_Test
    Y_norm = model_name.predict(X_test)
    
    # normalize predicted y
    Y_original=dataset_total.iloc[:,-1]
    Y_max=Y_original.max()
    Y_min=Y_original.min()
    real_y_predict = Y_norm *(Y_max-Y_min)+Y_min
    
    # normalize Y_test
    real_y_test = Y_test *(Y_max-Y_min)+Y_min
    
    # normalize real Y_daybefore
    real_y_daybefore = Y_daybefore * (Y_max-Y_min)+Y_min

    #Plot of the predicted prices versus the real prices
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.set_title("Return Over Time")
    plt.plot(real_y_predict, color = 'green', label = 'Predicted Return')
    plt.plot(real_y_test, color = 'red', label = 'Real Return')
    ax.set_ylabel("Return")
    ax.set_xlabel("Time (Days)")
    ax.legend()
    
    return Y_norm, real_y_test, real_y_predict, fig, real_y_daybefore


# In[5]:


#evaluate change in return

def return_change(real_y_daybefore, real_y_test, real_y_predict):
    """
    Calculate the percent change between each value and the day before
    
    Arguments:
    real_y_daybefore -- A tensor of shape (623,) that represents the prices of each day before each price in Y_test
    Y_test -- A tensor of shape (623,) that represents the normalized y values of the testing data
    y_predict -- A tensor of shape (623,) that represents the normalized y values of the model's predictions
    
    Returns:
    delta_predict -- A tensor of shape (623, ) that represents the difference between predicted and day before values
    delta_real -- A tensor of shape (623, ) that represents the difference between real and day before values
    fig -- A plot representing percent change in bitcoin price per day,
    """
    return_change_real = real_y_test - real_y_daybefore
    real_y_predict_reshape= np.reshape(real_y_predict,(real_y_predict.shape[0],))
    return_change_predict = real_y_predict_reshape - real_y_daybefore

    fig_2 = plt.figure(figsize=(10, 6))
    ax = fig_2.add_subplot(111)
    ax.set_title("Change in Return Per Day")
    plt.plot(return_change_predict, color='green', label = 'Predicted Return Change')
    plt.plot(return_change_real, color='red', label = 'Real Return Change')
    plt.ylabel("Return Change")
    plt.xlabel("Time (Days)")
    ax.legend()
    plt.show()
    return  return_change_predict, return_change_real, fig_2


# In[8]:


def binary_return(return_change_predict,return_change_real):
    """
    Converts return change to a binary 1 or 0, where 1 is an increase and 0 is a decrease/no change
    
    Arguments:
    delta_predict -- A tensor of shape (623, 1) that represents the predicted percent change in price
    delta_real -- A tensor of shape (623, 1) that represents the real percent change in price
    
    Returns:
    delta_predict_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_predict
    delta_real_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_real
    """
    #Empty arrays where a 1 represents an increase in price and a 0 represents a decrease in price
    return_change_predict_1_0 = np.empty(return_change_predict.shape)
    return_change_real_1_0 = np.empty(return_change_real.shape)

    #If the change in price is greater than zero, store it as a 1
    #If the change in price is less than zero, store it as a 0
    for i in range(return_change_predict.shape[0]):
        if return_change_predict[i] > 0:
            return_change_predict_1_0[i] = 1
        else:
            return_change_predict_1_0[i] = 0
  
    for i in range(return_change_real.shape[0]):
        if  return_change_real[i] > 0:
            return_change_real_1_0[i] = 1
        else:
            return_change_real_1_0[i] = 0
    return return_change_predict_1_0, return_change_real_1_0



# In[6]:


def find_positives_negatives(return_change_predict_1_0, return_change_real_1_0):
    """
    Finding the number of false positives, false negatives, true positives, true negatives
    
    Arguments: 
    delta_predict_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_predict
    delta_real_1_0 -- A tensor of shape (623, 1) that represents the binary version of delta_real
    
    Returns:
    true_pos -- An integer that represents the number of true positives achieved by the model
    false_pos -- An integer that represents the number of false positives achieved by the model
    true_neg -- An integer that represents the number of true negatives achieved by the model
    false_neg -- An integer that represents the number of false negatives achieved by the model
    """
    #Finding the number of false positive/negatives and true positives/negatives
    true_pos = 0
    false_pos = 0
    true_neg = 0
    false_neg = 0
    for i in range(return_change_real_1_0.shape[0]):
        real = return_change_real_1_0[i]
        predicted = return_change_predict_1_0[i]
        if real == 1:
            if predicted == 1:
                true_pos += 1
            else:
                false_neg += 1
        elif real == 0:
            if predicted == 0:
                true_neg += 1
            else:
                false_pos += 1
    return true_pos, false_pos, true_neg, false_neg

def classify_range(variable_name):
    
    classification[variable_name+'_range']=0

    for i in range(classification.shape[0]):
        if classification[variable_name][i]<=0.002 and classification[variable_name][i]>=-0.002:
            classification[variable_name+'_range'][i]=0
        
        elif classification[variable_name][i]<=-0.002 and classification[variable_name][i]>=-0.004:
            classification[variable_name+'_range'][i]=-1
        
        elif classification[variable_name][i]<=-0.004 and classification[variable_name][i]>=-0.006:
            classification[variable_name+'_range'][i]=-2
        
        elif classification[variable_name][i]<=-0.006 and classification[variable_name][i]>=-0.008:
            classification[variable_name+'_range'][i]=-3
        
        elif classification[variable_name][i]<=-0.008 and classification[variable_name][i]>=-0.010:
            classification[variable_name+'_range'][i]=-4
        
        elif classification[variable_name][i]<=-0.010 and classification[variable_name][i]>=-0.012:
            classification[variable_name+'_range'][i]=-5
        
        elif classification[variable_name][i]<=-0.012 and classification[variable_name][i]>=-0.014:
            classification[variable_name+'_range'][i]=-6
        
        elif classification[variable_name][i]<=-0.014 and classification[variable_name][i]>=-0.016:
            classification[variable_name+'_range'][i]=-7
        
        elif classification[variable_name][i]<=-0.016 and classification[variable_name][i]>=-0.018:
            classification[variable_name+'_range'][i]=-8
        
        elif classification[variable_name][i]<=-0.018 and classification[variable_name][i]>=-0.020:
            classification[variable_name+'_range'][i]=-9
        
        elif classification[variable_name][i]<=-0.020:
            classification[variable_name+'_range'][i]=-10
        
        #positive value
        elif classification[variable_name][i]<=0.004 and classification[variable_name][i]>=0.002:
            classification[variable_name+'_range'][i]=1
        
        elif classification[variable_name][i]<=0.006 and classification[variable_name][i]>=0.004:
            classification[variable_name+'_range'][i]=2
        
        elif classification[variable_name][i]<=0.008 and classification[variable_name][i]>=0.006:
            classification[variable_name+'_range'][i]=3
        
        elif classification[variable_name][i]<=0.010 and classification[variable_name][i]>=0.008:
            classification[variable_name+'_range'][i]=4
        
        elif classification[variable_name][i]<=0.012 and classification[variable_name][i]>=0.010:
            classification[variable_name+'_range'][i]=5
        
        elif classification[variable_name][i]<=0.014 and classification[variable_name][i]>=0.012:
            classification[variable_name+'_range'][i]=6
        
        elif classification[variable_name][i]<=0.016 and classification[variable_name][i]>=0.014:
            classification[variable_name+'_range'][i]=7
        
        elif classification[variable_name][i]<=0.018 and classification[variable_name][i]>=0.016:
            classification[variable_name+'_range'][i]=8
        
        elif classification[variable_name][i]<=0.020 and classification[variable_name][i]>=0.018:
            classification[variable_name+'_range'][i]=9
         
        else:
            classification[variable_name+'_range'][i]=10
    return classification

def find_the_successful_rate(classification):
    successful_number=0
    for i in range(classification.shape[0]):
        if classification['real_y_test_range'][i]==classification['real_y_predict_range'][i]:
            successful_number+=1
    successful_rate=round(successful_number/classification.shape[0],4)
    return successful_rate

# %%
#EOS
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("merge_EOS-USD.csv",0.7035)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .2)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("EOS NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_EOS.csv')
# Out:
# (426, 98)
# (426,)
# (180, 98)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 64)                6336
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 12,609
# Trainable params: 12,609
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 340 samples, validate on 86 samples
# Epoch 1/100
# 340/340 [==============================] - 0s 1ms/step - loss: 0.1133 - mean_squared_error: 0.1133 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 2/100
# 340/340 [==============================] - 0s 64us/step - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 3/100
# 340/340 [==============================] - 0s 41us/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 4/100
# 340/340 [==============================] - 0s 59us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 5/100
# 340/340 [==============================] - 0s 65us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch
# Epoch 46/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 47/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 48/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 49/100
# 340/340 [==============================] - 0s 59us/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 50/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 51/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 52/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 53/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 54/100
# 340/340 [==============================] - 0s 42us/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 55/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 56/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 57/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 58/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 59/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 60/100
# 340/340 [==============================] - 0s 51us/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 61/100
# 340/340 [==============================] - 0s 56us/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 62/100
# 340/340 [==============================] - 0s 50us/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 63/100
# 340/340 [==============================] - 0s 50us/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 64/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 65/100
# 340/340 [==============================] - 0s 54us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 66/100
# 340/340 [==============================] - 0s 45us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 67/100
# 340/340 [==============================] - 0s 44us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 68/100
# 340/340 [==============================] - 0s 37us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 69/100
# 340/340 [==============================] - 0s 34us/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 70/100
# 340/340 [==============================] - 0s 66us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 71/100
# 340/340 [==============================] - 0s 42us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 72/100
# 340/340 [==============================] - 0s 25us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 73/100
# 340/340 [==============================] - 0s 45us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 74/100
# 340/340 [==============================] - 0s 33us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 75/100
# 340/340 [==============================] - 0s 56us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 76/100
# 340/340 [==============================] - 0s 45us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 77/100
# 340/340 [==============================] - 0s 43us/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 78/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 79/100
# 340/340 [==============================] - 0s 48us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 80/100
# 340/340 [==============================] - 0s 45us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 81/100
# 340/340 [==============================] - 0s 34us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 82/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 83/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 84/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 85/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 86/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 87/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 88/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 89/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 90/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 91/100
# 340/340 [==============================] - 0s 48us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 92/100
# 340/340 [==============================] - 0s 42us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 93/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 94/100
# 340/340 [==============================] - 0s 44us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 95/100
# 340/340 [==============================] - 0s 47us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 96/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 97/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 98/100
# 340/340 [==============================] - 0s 37us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 99/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 100/100
# 340/340 [==============================] - 0s 35us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                    10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                    10
# 2018-12-04                    10
# 2018-12-05                    10
# 2018-12-06                    10
# 2018-12-07                    10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                    10
# 2018-12-14                    10
# 2018-12-15                    10
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                    10
# 2018-12-20                    10
# 2018-12-21                    10
# 2018-12-22                    10
# 2018-12-23                    10
# 2018-12-24                    10
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                   -10
# 2019-04-30                    10
# 2019-05-01                    -4
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                     0
# 2019-05-08                    -6
# 2019-05-09                     0
# 2019-05-10                   -10
# 2019-05-11                    -1
# 2019-05-12                   -10
# 2019-05-13                    -3
# 2019-05-14                    10
# 2019-05-15                   -10
# 2019-05-16                   -10
# 2019-05-17                   -10
# 2019-05-18                   -10
# 2019-05-19                     9
# 2019-05-20                   -10
# 2019-05-21                    10
# 2019-05-22                     5
#
# [180 rows x 4 columns]
# 0.2444
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is -1.2636846773044554
# Annulized Sharpe Ratio for buy and hold strategy is 0.7832429664222199

# %%
#ZEC
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("merge_ZEC-USD.csv",0.7885)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .2)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("ZEC NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_ZEC.csv')
# Out:
# (670, 112)
# (670,)
# (180, 112)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 64)                7232
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_39 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 13,505
# Trainable params: 13,505
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 536 samples, validate on 134 samples
# Epoch 1/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 2/100
# 536/536 [==============================] - 0s 98us/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 3/100
# 536/536 [==============================] - 0s 130us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 4/100
# 536/536 [==============================] - 0s 108us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 5/100
# 536/536 [==============================] - 0s 74us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 6/100
# 536/536 [==============================] - 0s 112us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 7/100
# 536/536 [==============================] - 0s 87us/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 8/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 9/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 10/100
# 536/536 [==============================] - 0s 94us/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 11/100
# 536/536 [==============================] - 0s 40us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 12/100
# 536/536 [==============================] - 0s 138us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 13/100
# 536/536 [==============================] - 0s 102us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 14/100
# 536/536 [==============================] - 0s 75us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 15/100
# 536/536 [==============================] - 0s 92us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 16/100
# 536/536 [==============================] - 0s 98us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 17/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 18/100
# 536/536 [==============================] - 0s 65us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 19/100
# 536/536 [==============================] - 0s 72us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 20/100
# 536/536 [==============================] - 0s 56us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 21/100
# 536/536 [==============================] - 0s 81us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 22/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 23/100
# 536/536 [==============================] - 0s 49us/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 24/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 25/100
# 536/536 [==============================] - 0s 44us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 26/100
# 536/536 [==============================] - 0s 44us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 27/100
# 536/536 [==============================] - 0s 70us/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 28/100
# 536/536 [==============================] - 0s 37us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 29/100
# 536/536 [==============================] - 0s 66us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 30/100
# 536/536 [==============================] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.00 - 0s 51us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 31/100
# 536/536 [==============================] - 0s 67us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 32/100
# 536/536 [==============================] - 0s 79us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 33/100
# 536/536 [==============================] - 0s 68us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 34/100
# 536/536 [==============================] - 0s 68us/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 35/100
# 536/536 [==============================] - 0s 62us/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 36/100
# 536/536 [==============================] - 0s 73us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 37/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 38/100
# 536/536 [==============================] - 0s 82us/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 39/100
# 536/536 [==============================] - 0s 94us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 40/100
# 536/536 [==============================] - 0s 65us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 41/100
# 536/536 [==============================] - 0s 44us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 42/100
# 536/536 [==============================] - 0s 65us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 43/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 44/100
# 536/536 [==============================] - 0s 87us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 45/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 46/100
# 536/536 [==============================] - 0s 62us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 47/100
# 536/536 [==============================] - 0s 104us/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 48/100
# 536/536 [==============================] - 0s 89us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 49/100
# 536/536 [==============================] - 0s 86us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 50/100
# 536/536 [==============================] - 0s 88us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 51/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 52/100
# 536/536 [==============================] - 0s 52us/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 53/100
# 536/536 [==============================] - 0s 80us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 54/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 55/100
# 536/536 [==============================] - 0s 93us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 56/100
# 536/536 [==============================] - 0s 59us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 57/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 58/100
# 536/536 [==============================] - 0s 74us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 59/100
# 536/536 [==============================] - 0s 68us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 60/100
# 536/536 [==============================] - 0s 45us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 61/100
# 536/536 [==============================] - 0s 69us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 62/100
# 536/536 [==============================] - 0s 86us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 63/100
# 536/536 [==============================] - 0s 116us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 64/100
# 536/536 [==============================] - 0s 88us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 65/100
# 536/536 [==============================] - 0s 60us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 66/100
# 536/536 [==============================] - 0s 52us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 67/100
# 536/536 [==============================] - 0s 87us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 68/100
# 536/536 [==============================] - 0s 51us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 69/100
# 536/536 [==============================] - 0s 74us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 70/100
# 536/536 [==============================] - 0s 63us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 71/100
# 536/536 [==============================] - 0s 50us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 72/100
# 536/536 [==============================] - 0s 92us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 73/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 74/100
# 536/536 [==============================] - 0s 87us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 75/100
# 536/536 [==============================] - 0s 68us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 76/100
# 536/536 [==============================] - 0s 87us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 77/100
# 536/536 [==============================] - 0s 75us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 78/100
# 536/536 [==============================] - 0s 86us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 79/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 80/100
# 536/536 [==============================] - 0s 88us/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 81/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 82/100
# 536/536 [==============================] - 0s 64us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 83/100
# 536/536 [==============================] - 0s 61us/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 84/100
# 536/536 [==============================] - 0s 69us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 85/100
# 536/536 [==============================] - 0s 42us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 86/100
# 536/536 [==============================] - 0s 80us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 87/100
# 536/536 [==============================] - 0s 96us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 88/100
# 536/536 [==============================] - 0s 145us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 89/100
# 536/536 [==============================] - 0s 94us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 90/100
# 536/536 [==============================] - 0s 94us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 91/100
# 536/536 [==============================] - 0s 88us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 92/100
# 536/536 [==============================] - 0s 62us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 93/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 94/100
# 536/536 [==============================] - 0s 62us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 95/100
# 536/536 [==============================] - 0s 65us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 96/100
# 536/536 [==============================] - 0s 96us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 97/100
# 536/536 [==============================] - 0s 110us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 98/100
# 536/536 [==============================] - 0s 58us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 99/100
# 536/536 [==============================] - 0s 81us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 100/100
# 536/536 [==============================] - 0s 62us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:319: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:347: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:328: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:359: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:344: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:313: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.058028        0.057957                -10
# 2018-11-26     0.094647        0.070278                 10
# 2018-11-27     0.094796        0.124952                 10
# 2018-11-28     0.101435        0.078296                 10
# 2018-11-29    -0.081898        0.091269                -10
# 2018-11-30    -0.003578        0.030710                 -1
# 2018-12-01    -0.011763       -0.027712                 -5
# 2018-12-02    -0.111014        0.083460                -10
# 2018-12-03     0.052290        0.011008                 10
# 2018-12-04    -0.115457        0.108593                -10
# 2018-12-05    -0.119473        0.038229                -10
# 2018-12-06     0.029063        0.067398                 10
# 2018-12-07    -0.037935        0.112314                -10
# 2018-12-08     0.056453        0.047932                 10
# 2018-12-09    -0.067905        0.100666                -10
# 2018-12-10    -0.047627        0.046408                -10
# 2018-12-11     0.028524        0.054119                 10
# 2018-12-12    -0.069692        0.069121                -10
# 2018-12-13    -0.043167        0.058516                -10
# 2018-12-14     0.022861        0.076921                 10
# 2018-12-15     0.020767        0.091768                 10
# 2018-12-16     0.108312        0.077991                 10
# 2018-12-17     0.039336        0.076413                 10
# 2018-12-18    -0.025736        0.110588                -10
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is -0.015614998574989283
# Annulized Sharpe Ratio for buy and hold strategy is -0.2905846972302419

# %%
#ETH
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("merge_ETH-USD.csv",0.8614)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .2)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("ETH NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_ETH.csv')
# Out:
# (1118, 110)
# (1118,)
# (180, 110)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 64)                7104
# _________________________________________________________________
# dense_42 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 13,377
# Trainable params: 13,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 894 samples, validate on 224 samples
# Epoch 1/100
# 894/894 [==============================] - 1s 849us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 2/100
# 894/894 [==============================] - 0s 43us/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 3/100
# 894/894 [==============================] - 0s 40us/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 4/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 5/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 6/100
# 894/894 [==============================] - 0s 54us/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 7/100
# 894/894 [==============================] - 0s 68us/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 8/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 9/100
# 894/894 [==============================] - 0s 70us/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 10/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 11/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 12/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 13/100
# 894/894 [==============================] - 0s 48us/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 14/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 15/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 16/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 17/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 18/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 19/100
# 894/894 [==============================] - 0s 31us/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 20/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 21/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 22/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 23/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 24/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 25/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 26/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 27/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 28/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 29/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 30/100
# 894/894 [==============================] - 0s 54us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 31/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 32/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 33/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 34/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 35/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 36/100
# 894/894 [==============================] - 0s 70us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 37/100
# 894/894 [==============================] - 0s 70us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 38/100
# 894/894 [==============================] - 0s 81us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 39/100
# 894/894 [==============================] - 0s 39us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 40/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 41/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 42/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 43/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 44/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 45/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 46/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 47/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 48/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 49/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 50/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 51/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 52/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 53/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 54/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 55/100
# 894/894 [==============================] - 0s 54us/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 56/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 57/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 58/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 59/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 60/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 61/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 62/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 63/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 64/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 65/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 66/100
# 894/894 [==============================] - 0s 49us/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 67/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 68/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 69/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 70/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 71/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 72/100
# 894/894 [==============================] - 0s 41us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 73/100
# 894/894 [==============================] - 0s 24us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 74/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 75/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 76/100
# 894/894 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 77/100
# 894/894 [==============================] - 0s 46us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 78/100
# 894/894 [==============================] - 0s 70us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 79/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 80/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 81/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 82/100
# 894/894 [==============================] - 0s 50us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 83/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 84/100
# 894/894 [==============================] - 0s 56us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 85/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 86/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 87/100
# 894/894 [==============================] - 0s 66us/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 88/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 89/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 90/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 91/100
# 894/894 [==============================] - 0s 55us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 92/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 93/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 94/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 95/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 96/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 97/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 98/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 99/100
# 894/894 [==============================] - 0s 52us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 100/100
# 894/894 [==============================] - 0s 35us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:319: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:328: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:344: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:347: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:359: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:313: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-25    -0.067495        0.115962                -10
# 2018-11-26     0.012125        0.126509                  6
# 2018-11-27     0.115165       -0.003875                 10
# 2018-11-28    -0.043945        0.171995                -10
# 2018-11-29    -0.039241        0.040129                -10
# 2018-11-30     0.049880        0.016107                 10
# 2018-12-01    -0.021435        0.117451                -10
# 2018-12-02    -0.066661        0.040801                -10
# 2018-12-03     0.014691        0.030783                  7
# 2018-12-04    -0.075123        0.052688                -10
# 2018-12-05    -0.109678        0.014161                -10
# 2018-12-06     0.035165        0.125065                 10
# 2018-12-07    -0.023181        0.100774                -10
# 2018-12-08     0.032590        0.131241                 10
# 2018-12-09    -0.039398        0.164997                -10
# 2018-12-10    -0.029217        0.073655                -10
# 2018-12-11     0.028052        0.035434                 10
# 2018-12-12    -0.045625        0.188667                -10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                     3
# 2019-05-17                   -10
# 2019-05-18                    10
# 2019-05-19                     6
# 2019-05-20                   -10
# 2019-05-21                    -1
# 2019-05-22                   -10
#
# [180 rows x 4 columns]
# 0.1944
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is -0.08440502422745537
# Annulized Sharpe Ratio for buy and hold strategy is 1.056727261539883

# %%
#XRP
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("merge_XRP-USD.csv",0.8798)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .2)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("XRP NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_XRP.csv')
# Out:
# (1316, 110)
# (1316,)
# (180, 110)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 64)                7104
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_47 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 13,377
# Trainable params: 13,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1052 samples, validate on 264 samples
# Epoch 1/100
# 1052/1052 [==============================] - 1s 770us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 2/100
# 1052/1052 [==============================] - 0s 65us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 3/100
# 1052/1052 [==============================] - 0s 50us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 4/100
# 1052/1052 [==============================] - 0s 65us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 5/100
# 1052/1052 [==============================] - 0s 57us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 6/100
# 1052/1052 [==============================] - 0s 62us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 7/100
# 1052/1052 [==============================] - 0s 62us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 8/100
# 1052/1052 [==============================] - 0s 59us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 9/100
# 1052/1052 [==============================] - 0s 56us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 10/100
# 1052/1052 [==============================] - 0s 59us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 11/100
# 1052/1052 [==============================] - 0s 59us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 12/100
# 1052/1052 [==============================] - 0s 40us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 13/100
# 1052/1052 [==============================] - 0s 68us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 14/100
# 1052/1052 [==============================] - 0s 41us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 15/100
# 1052/1052 [==============================] - 0s 65us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 16/100
# 1052/1052 [==============================] - 0s 43us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 17/100
# 1052/1052 [==============================] - 0s 47us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 18/100
# 1052/1052 [==============================] - 0s 44us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 19/100
# 1052/1052 [==============================] - 0s 64us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 20/100
# 1052/1052 [==============================] - 0s 47us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 21/100
# 1052/1052 [==============================] - 0s 36us/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 22/100
# 1052/1052 [==============================] - 0s 58us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 23/100
# 1052/1052 [==============================] - 0s 48us/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 24/100
# 1052/1052 [==============================] - 0s 65us/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 25/100
# 1052/1052 [==============================] - 0s 50us/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 26/100
# 1052/1052 [==============================] - 0s 54us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 27/100
# 1052/1052 [==============================] - 0s 46us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 28/100
# 1052/1052 [==============================] - 0s 59us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 29/100
# 1052/1052 [==============================] - 0s 50us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 30/100
# 1052/1052 [==============================] - 0s 40us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 31/100
# 1052/1052 [==============================] - 0s 36us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch
# 2019-05-18    -0.045878        0.046042                -10
# 2019-05-19    -0.005510        0.037466                 -2
# 2019-05-20    -0.063964        0.100840                -10
# 2019-05-21     0.024213        0.056753                 10
# 2019-05-22     0.008668        0.063113                  4
#
#             real_y_predict_range
# Date
# 2018-11-25                    10
# 2018-11-26                    10
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                    10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                    10
# 2018-12-04                    10
# 2018-12-05                    10
# 2018-12-06                    10
# 2018-12-07                    10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                    10
# 2018-12-14                    10
# 2018-12-15                    10
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                    10
# 2018-12-20                    10
# 2018-12-21                     3
# 2018-12-22                    10
# 2018-12-23                    10
# 2018-12-24                     9
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                    10
# 2019-05-08                    10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                    10
# 2019-05-17                    10
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    10
# 2019-05-22                    10
#
# [180 rows x 4 columns]
# 0.1944
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is -0.21716971168481308
# Annulized Sharpe Ratio for buy and hold strategy is -0.32246454698985777

# %%
#LTC
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("merge_LTC-USD.csv",0.9077)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .2)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("LTC NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_LTC.csv')
# Out:
# (1770, 108)
# (1770,)
# (180, 108)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 64)                6976
# _________________________________________________________________
# dense_50 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_51 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_52 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 13,249
# Trainable params: 13,249
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1416 samples, validate on 354 samples
# Epoch 1/100
# 1416/1416 [==============================] - 2s 1ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 2/100
# 1416/1416 [==============================] - 0s 63us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 3/100
# 1416/1416 [==============================] - 0s 76us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 4/100
# 1416/1416 [==============================] - 0s 78us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 5/100
# 1416/1416 [==============================] - 0s 66us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch
# 2018-12-23                    10
# 2018-12-24                    10
# ...                          ...
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                    10
# 2019-05-08                    10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                    10
# 2019-05-17                    10
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    10
# 2019-05-22                    10
#
# [180 rows x 4 columns]
# 0.3444
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 1.4975599686086671
# Annulized Sharpe Ratio for buy and hold strategy is 1.4936024962189969

# %%
#Bitcoin
#load the data
X_train, Y_train, X_test, Y_test, dataset_total,Y_daybefore,line = load_data("Bitcoin.csv",0.9428)
print (X_train.shape)
print (Y_train.shape)
print (X_test.shape)
print (Y_test.shape)

#initialize the model
model = initialize_model(0.2)
print (model.summary())

#fit the model
model_32,history_32 = fit_model(model, X_train, Y_train, 32, 100, .3)

#test the model
y_predict, real_y_test, real_y_predict, fig,real_y_daybefore =test_model(model_32, X_test, Y_test)

#return change
return_change_predict, return_change_real, fig_2 = return_change(real_y_daybefore, real_y_test, real_y_predict)

classification=pd.DataFrame({'real_y_test':real_y_test,'real_y_predict':real_y_predict.reshape(real_y_test.shape[0],)})
classification.index=dataset_total.index[line:]

classify_range('real_y_test')
classify_range('real_y_predict')

print(classification)

successful_rate=find_the_successful_rate(classification)
print(successful_rate)

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
ax.set_title("Bitcoin NN3 Predicted Return VS Real Return")
plt.plot(classification['real_y_predict'], color='green', label = 'Predicted Return')
plt.plot(classification['real_y_test'], color='red', label = 'Real Return')
plt.ylabel("Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

classification.head(10)
test_set=pd.DataFrame(classification['real_y_predict_range'])
type(test_set)
test_set.columns=['classification_predict']
test_set['Price']=dataset_total['Adj Close'][line:]
test_set['Position']=0

for i in range(test_set.shape[0]):
    if test_set['classification_predict'][i]<0:
        test_set['Position'][i]=-1
    elif test_set['classification_predict'][i]==0:
        test_set['Position'][i]=test_set['Position'][i-1]
    else:
        test_set['Position'][i]=1
test_set['daily_return']=test_set['Price'].pct_change()
test_set['daily_return']=test_set['daily_return'].shift(-1)
test_set['strategy_daily_return']=test_set['Position']*test_set['daily_return']
test_set=test_set.dropna()
test_set['buy_cumulative_return']=1
test_set=test_set.dropna()
test_set['buy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['buy_cumulative_return'][i]=test_set['daily_return'][i]+1
    else:
        test_set['buy_cumulative_return'][i]=(test_set['daily_return'][i]+1)* test_set['buy_cumulative_return'][i-1]

test_set['strategy_cumulative_return']=float(0)
for i in range(test_set.shape[0]):
    if i<=0:
        test_set['strategy_cumulative_return'][i]=test_set['strategy_daily_return'][i]+1
    else:
        test_set['strategy_cumulative_return'][i]=(test_set['strategy_daily_return'][i]+1)* test_set['strategy_cumulative_return'][i-1]

fig_n = plt.figure(figsize=(10, 6))
ax = fig_n.add_subplot(111)
plt.plot(test_set['strategy_cumulative_return'], color='red', label = 'Trading Srategy Return')
plt.plot(test_set['buy_cumulative_return'], color='black', label = 'Buy-and-hold Return')
plt.ylabel("Cumulative Return")
plt.xlabel("Time (Days)")
ax.legend()
plt.style.use('ggplot')
plt.show()

#calculate trading strategy sharpe ratio
risk_free_rate=0.002

test_set['excess_return']=test_set['strategy_daily_return']-risk_free_rate
test_set['excess_return'].std()
test_set['excess_return'].mean()
daily_sharpe=test_set['excess_return'].mean()/test_set['excess_return'].std()
print('Annulized Sharpe Ratio is '+str(daily_sharpe*252**0.5))

#calculate buy and hold sharpe ratio
test_set['excess_return_buy']=test_set['daily_return']-risk_free_rate
test_set['excess_return_buy'].std()
test_set['excess_return_buy'].mean()
daily_sharpe_2=test_set['excess_return_buy'].mean()/test_set['excess_return_buy'].std()
print('Annulized Sharpe Ratio for buy and hold strategy is '+str(daily_sharpe_2*252**0.5))

Sharpe=pd.DataFrame(test_set['excess_return_buy'])
Sharpe['excess_return_str']=test_set['excess_return']

####rename for each cryptocurrency
Sharpe.to_csv('Sharpe_NN3_Bit.csv')
# Out:
# (2964, 105)
# (2964,)
# (180, 105)
# (180,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 64)                6784
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 13,057
# Trainable params: 13,057
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 2074 samples, validate on 890 samples
# Epoch 1/100
# 2074/2074 [==============================] - 0s 222us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 2/100
# 2074/2074 [==============================] - 0s 31us/step - loss: 8.0502e-04 - mean_squared_error: 8.0502e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 3/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 7.4097e-04 - mean_squared_error: 7.4097e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 4/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 6.9009e-04 - mean_squared_error: 6.9009e-04 - val_loss: 8.7398e-04 - val_mean_squared_error: 8.7398e-04
# Epoch 5/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 6.6416e-04 - mean_squared_error: 6.6416e-04 - val_loss: 8.6342e-04 - val_mean_squared_error: 8.6342e-04
# Epoch 6/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 6.6786e-04 - mean_squared_error: 6.6786e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 7/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 6.5895e-04 - mean_squared_error: 6.5895e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 8/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 6.4099e-04 - mean_squared_error: 6.4099e-04 - val_loss: 8.7407e-04 - val_mean_squared_error: 8.7407e-04
# Epoch 9/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 6.3495e-04 - mean_squared_error: 6.3495e-04 - val_loss: 6.8621e-04 - val_mean_squared_error: 6.8621e-04
# Epoch 10/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 6.0728e-04 - mean_squared_error: 6.0728e-04 - val_loss: 5.8239e-04 - val_mean_squared_error: 5.8239e-04
# Epoch 11/100
# 2074/2074 [==============================] - 0s 36us/step - loss: 5.9388e-04 - mean_squared_error: 5.9388e-04 - val_loss: 6.1579e-04 - val_mean_squared_error: 6.1579e-04
# Epoch 12/100
# 2074/2074 [==============================] - 0s 37us/step - loss: 5.8639e-04 - mean_squared_error: 5.8639e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 13/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 5.8873e-04 - mean_squared_error: 5.8873e-04 - val_loss: 7.4732e-04 - val_mean_squared_error: 7.4732e-04
# Epoch 14/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 6.2775e-04 - mean_squared_error: 6.2775e-04 - val_loss: 6.0692e-04 - val_mean_squared_error: 6.0692e-04
# Epoch 15/100
# 2074/2074 [==============================] - 0s 36us/step - loss: 5.6649e-04 - mean_squared_error: 5.6649e-04 - val_loss: 6.5055e-04 - val_mean_squared_error: 6.5055e-04
# Epoch 16/100
# 2074/2074 [==============================] - 0s 31us/step - loss: 5.5504e-04 - mean_squared_error: 5.5504e-04 - val_loss: 6.4679e-04 - val_mean_squared_error: 6.4679e-04
# Epoch 17/100
# 2074/2074 [==============================] - 0s 34us/step - loss: 5.5478e-04 - mean_squared_error: 5.5478e-04 - val_loss: 6.5101e-04 - val_mean_squared_error: 6.5101e-04
# Epoch 18/100
# 2074/2074 [==============================] - 0s 33us/step - loss: 5.2068e-04 - mean_squared_error: 5.2068e-04 - val_loss: 7.8861e-04 - val_mean_squared_error: 7.8861e-04
# Epoch 19/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 5.8430e-04 - mean_squared_error: 5.8430e-04 - val_loss: 6.0456e-04 - val_mean_squared_error: 6.0456e-04
# Epoch 20/100
# 2074/2074 [==============================] - 0s 32us/step - loss: 5.0849e-04 - mean_squared_error: 5.0849e-04 - val_loss: 6.1236e-04 - val_mean_squared_error: 6.1236e-04
# Epoch 21/100
# 2074/2074 [==============================] - 0s 36us/step - loss: 5.3355e-04 - mean_squared_error: 5.3355e-04 - val_loss: 8.5904e-04 - val_mean_squared_error: 8.5904e-04
# Epoch 22/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 5.4249e-04 - mean_squared_error: 5.4249e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 23/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 4.5280e-04 - mean_squared_error: 4.5280e-04 - val_loss: 5.6548e-04 - val_mean_squared_error: 5.6548e-04
# Epoch 24/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 4.2176e-04 - mean_squared_error: 4.2176e-04 - val_loss: 5.2754e-04 - val_mean_squared_error: 5.2754e-04
# Epoch 25/100
# 2074/2074 [==============================] - 0s 44us/step - loss: 4.3900e-04 - mean_squared_error: 4.3900e-04 - val_loss: 4.2651e-04 - val_mean_squared_error: 4.2651e-04
# Epoch 26/100
- val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 88/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 2.1182e-04 - mean_squared_error: 2.1182e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 89/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 1.9122e-04 - mean_squared_error: 1.9122e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 90/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 1.9812e-04 - mean_squared_error: 1.9812e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 91/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 1.8150e-04 - mean_squared_error: 1.8150e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 92/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 1.8242e-04 - mean_squared_error: 1.8242e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 93/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 1.8411e-04 - mean_squared_error: 1.8411e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 94/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 1.9681e-04 - mean_squared_error: 1.9681e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 95/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 1.8206e-04 - mean_squared_error: 1.8206e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 96/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 1.9498e-04 - mean_squared_error: 1.9498e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 97/100
# 2074/2074 [==============================] - 0s 36us/step - loss: 1.7679e-04 - mean_squared_error: 1.7679e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 98/100
# 2074/2074 [==============================] - 0s 30us/step - loss: 1.7103e-04 - mean_squared_error: 1.7103e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 99/100
# 2074/2074 [==============================] - 0s 38us/step - loss: 1.9118e-04 - mean_squared_error: 1.9118e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 100/100
# 2074/2074 [==============================] - 0s 36us/step - loss: 1.8832e-04 - mean_squared_error: 1.8832e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:347: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:338: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:319: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:359: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:328: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:313: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:335: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:344: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             real_y_test  real_y_predict  real_y_test_range  \
# Date
# 2018-11-24     0.038930       -0.013801                 10
# 2018-11-25    -0.054833        0.067014                -10
# 2018-11-26     0.010146       -0.030538                  5
# 2018-11-27     0.115240        0.052476                 10
# 2018-11-28     0.005427        0.100945                  2
# 2018-11-29    -0.064623        0.152933                -10
# 2018-11-30     0.046834       -0.163324                 10
# 2018-12-01    -0.012770        0.034689                 -6
# 2018-12-02    -0.065748        0.043620                -10
# 2018-12-03     0.019897       -0.070237                  9
# 2018-12-04    -0.053416        0.053262                -10
# 2018-12-05    -0.067518       -0.144074                -10
# 2018-12-06    -0.018538       -0.032873                 -9
# 2018-12-07     0.011840       -0.050179                  5
# 2018-12-08     0.038072        0.129991                 10
# 2018-12-09    -0.034981        0.165337                -10
# 2018-12-10    -0.019076        0.142922                 -9
# 2018-12-11     0.024866        0.111183                 10
# 2018-12-12    -0.051779        0.201905                -10
# 2018-12-13    -0.021067        0.018432                -10
# 2018-12-14    -0.000918        0.131765                  0
# 2018-12-15     0.007072       -0.006664                  3
# 2018-12-16     0.089950        0.091377                 10
# 2018-12-17     0.047252        0.296369                 10
# 2018-12-18     0.005568        0.335580                  2
# 2018-12-19     0.107351        0.217738                 10
# 2018-12-20    -0.057726        0.239767                -10
# 2018-12-21     0.037558        0.263588                 10
# 2018-12-22    -0.009297        0.174764                 -4
# 2018-12-23     0.018545        0.294236                  9
# ...                 ...             ...                ...
# 2019-04-22    -0.015259        0.442512                 -7
# 2019-04-23    -0.053517        0.406719                -10
# 2019-04-24     0.013834        0.236580                  6
# 2019-04-25    -0.000881        0.334713                  0
# 2019-04-26     0.008217        0.118164                  4
# 2019-04-27    -0.006542        0.369838                 -3
# 2019-04-28     0.021512        0.311362                 10
# 2019-04-29     0.007270        0.351908                  3
# 2019-04-30     0.020629        0.462869                 10
# 2019-05-01     0.045932        0.313487                 10
# 2019-05-02     0.015069        0.407941                  7
# 2019-05-03    -0.007866        0.469396                 -3
# 2019-05-04    -0.007934        0.433628                 -3
# 2019-05-05     0.012421        0.311640                  6
# 2019-05-06     0.030782        0.444831                 10
# 2019-05-07     0.028881        0.456614                 10
# 2019-05-08     0.030190        0.310721                 10
# 2019-05-09     0.131021        0.468733                 10
# 2019-05-10    -0.029720        0.443524                -10
# 2019-05-11     0.118770        0.436589                 10
# 2019-05-12     0.022260        0.408064                 10
# 2019-05-13     0.025526        0.372926                 10
# 2019-05-14    -0.037845        0.388083                -10
# 2019-05-15    -0.063772        0.178241                -10
# 2019-05-16    -0.014363       -0.039583                 -7
# 2019-05-17     0.127587        0.037496                 10
# 2019-05-18    -0.023782        0.123161                -10
# 2019-05-19    -0.006296        0.160065                 -3
# 2019-05-20    -0.040393        0.059403                -10
# 2019-05-21     0.033499       -0.015413                 10
#
#             real_y_predict_range
# Date
# 2018-11-24                    -6
# 2018-11-25                    10
# 2018-11-26                   -10
# 2018-11-27                    10
# 2018-11-28                    10
# 2018-11-29                    10
# 2018-11-30                   -10
# 2018-12-01                    10
# 2018-12-02                    10
# 2018-12-03                   -10
# 2018-12-04                    10
# 2018-12-05                   -10
# 2018-12-06                   -10
# 2018-12-07                   -10
# 2018-12-08                    10
# 2018-12-09                    10
# 2018-12-10                    10
# 2018-12-11                    10
# 2018-12-12                    10
# 2018-12-13                     9
# 2018-12-14                    10
# 2018-12-15                    -3
# 2018-12-16                    10
# 2018-12-17                    10
# 2018-12-18                    10
# 2018-12-19                    10
# 2018-12-20                    10
# 2018-12-21                    10
# 2018-12-22                    10
# 2018-12-23                    10
# ...                          ...
# 2019-04-22                    10
# 2019-04-23                    10
# 2019-04-24                    10
# 2019-04-25                    10
# 2019-04-26                    10
# 2019-04-27                    10
# 2019-04-28                    10
# 2019-04-29                    10
# 2019-04-30                    10
# 2019-05-01                    10
# 2019-05-02                    10
# 2019-05-03                    10
# 2019-05-04                    10
# 2019-05-05                    10
# 2019-05-06                    10
# 2019-05-07                    10
# 2019-05-08                    10
# 2019-05-09                    10
# 2019-05-10                    10
# 2019-05-11                    10
# 2019-05-12                    10
# 2019-05-13                    10
# 2019-05-14                    10
# 2019-05-15                    10
# 2019-05-16                   -10
# 2019-05-17                    10
# 2019-05-18                    10
# 2019-05-19                    10
# 2019-05-20                    10
# 2019-05-21                    -7
#
# [180 rows x 4 columns]
# 0.2167
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Annulized Sharpe Ratio is 0.8974889862098222
# Annulized Sharpe Ratio for buy and hold strategy is 1.0620883732767286
